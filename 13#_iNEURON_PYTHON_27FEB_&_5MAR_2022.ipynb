# %% [markdown]
# # 27th FEB

# %%
import pandas as pd

# %%
# Read html.
df = pd.read_html('https://www.basketball-reference.com/leagues/NBA_2015_totals.html')
df

# o/p in consol is not readable for us so solution for this is in below cell.
# Out:
# [      Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
#  0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
#  1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
#  2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
#  3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
#  4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
#  ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
#  670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
#  671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
#  672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
#  673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
#  674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
# The draw back to read the info from html is that it will only take the tabuler data in the consol.

# %%
df = pd.read_html('https://www.basketball-reference.com/leagues/NBA_2015_totals.html')
df
type(df)
# Out:
# list

# %%
len(df)
# Out:
# 1

# %%
df[0]
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
type(df[0])
# Out:
# pandas.core.frame.DataFrame

# %%
df1 = df[0]
df1
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
df1.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
df1.head(3)
# Out:
#   Rk        Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  DRB  \
# 0  1    Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79  222
# 1  2  Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9   19
# 2  3  Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199  324
#
#    TRB AST STL BLK TOV   PF  PTS
# 0  301  68  27  22  60  147  398
# 1   28  16  16   7  14   24   94
# 2  523  66  38  86  99  222  537
#
# [3 rows x 30 columns]

# %%
df1.tail(3)
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
#      DRB  TRB  AST STL BLK TOV   PF  PTS
# 672  114  166   38  38   8  42   56  386
# 673  265  362  100  34  49  62  156  472
# 674  319  465  113  18  52  76  205  833
#
# [3 rows x 30 columns]

# %%
df1.dtypes
# Out:
# Rk        object
# Player    object
# Pos       object
# Age       object
# Tm        object
# G         object
# GS        object
# MP        object
# FG        object
# FGA       object
# FG%       object
# 3P        object
# 3PA       object
# 3P%       object
# 2P        object
# 2PA       object
# 2P%       object
# eFG%      object
# FT        object
# FTA       object
# FT%       object
# ORB       object
# DRB       object
# TRB       object
# AST       object
# STL       object
# BLK       object
# TOV       object
# PF        object
# PTS       object
# dtype: object

# %%
dx=df1.dtypes

# %%
dx['Class']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Class'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df1[['Age','GS']]
# Out:
#     Age  GS
# 0    24  22
# 1    20   0
# 2    21  67
# 3    28   0
# 4    29  72
# ..   ..  ..
# 670  26  68
# 671  26  48
# 672  26  20
# 673  22  45
# 674  25  59
#
# [675 rows x 2 columns]

# %%
df1
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
# Now to store this above cell data into the seperate file i.e. either in csv or xlxs or any other thing.

df1.to_csv('NBA.csv',index=False)

# %%
ls
# Out:
#  MongoDB/
# 1#_iNEURON_PYTHON_4DEC_&_5DEC_2021.ipynb
# 10#_iNEURON_PYTHON_12FEB_&_13FEB_2022.ipynb
# 10.1#_iNEURON_PYTHON_12FEB_&_13FEB_2022.ipynb
# 10.2#_iNEURON_PYTHON_12FEB_&_13FEB_2022.ipynb
# 11#_iNEURON_PYTHON_19FEB_&_20FEB_2022.ipynb
# 12#_iNEURON_PYTHON_26FEB_&_27FEB_2022.ipynb
# 13#_iNEURON_PYTHON_5MAR_&_6MAR_2022.ipynb
# 2#_iNEURON_PYTHON_18DEC_&_19DEC_2021.ipynb
# 3#_iNEURON_PYTHON_20DEC_&_21DEC_2021.ipynb
# 4#_iNEURON_PYTHON_23DEC_2021.ipynb
# 5#_iNEURON_PYTHON_8JAN_&_9JAN_2022.ipynb
# 6#_iNEURON_PYTHON_15JAN_&_16JAN_2022.ipynb
# 7#_iNEURON_PYTHON_22JAN_&_23JAN_2022.ipynb
# 7.1#_iNEURON_PYTHON_22JAN_&_23JAN_2022.ipynb
# 8#_iNEURON_PYTHON_29JAN_&_30JAN_2022.ipynb
# 9#_iNEURON_PYTHON_5FEB_&_6FEB_2022.ipynb
# DATA SET/
# FILES/
# LUSID Excel - Manage Orders.xlsx
# NBA.csv
# PycharmProjects/
# glass.csv
# glass.data
# google.txt
# ineuron.db
# jobdb.db
# ohana-api-master/
# person.db
# sample-excel-master/

# %%
df1.to_excel('NBA.xlsx',index=False)

# %%
ls
# Out:
#  MongoDB/
# 1#_iNEURON_PYTHON_4DEC_&_5DEC_2021.ipynb
# 10#_iNEURON_PYTHON_12FEB_&_13FEB_2022.ipynb
# 10.1#_iNEURON_PYTHON_12FEB_&_13FEB_2022.ipynb
# 10.2#_iNEURON_PYTHON_12FEB_&_13FEB_2022.ipynb
# 11#_iNEURON_PYTHON_19FEB_&_20FEB_2022.ipynb
# 12#_iNEURON_PYTHON_26FEB_&_27FEB_2022.ipynb
# 13#_iNEURON_PYTHON_5MAR_&_6MAR_2022.ipynb
# 2#_iNEURON_PYTHON_18DEC_&_19DEC_2021.ipynb
# 3#_iNEURON_PYTHON_20DEC_&_21DEC_2021.ipynb
# 4#_iNEURON_PYTHON_23DEC_2021.ipynb
# 5#_iNEURON_PYTHON_8JAN_&_9JAN_2022.ipynb
# 6#_iNEURON_PYTHON_15JAN_&_16JAN_2022.ipynb
# 7#_iNEURON_PYTHON_22JAN_&_23JAN_2022.ipynb
# 7.1#_iNEURON_PYTHON_22JAN_&_23JAN_2022.ipynb
# 8#_iNEURON_PYTHON_29JAN_&_30JAN_2022.ipynb
# 9#_iNEURON_PYTHON_5FEB_&_6FEB_2022.ipynb
# DATA SET/
# FILES/
# LUSID Excel - Manage Orders.xlsx
# NBA.csv
# NBA.xlsx
# PycharmProjects/
# glass.csv
# glass.data
# google.txt
# ineuron.db
# jobdb.db
# ohana-api-master/
# person.db
# sample-excel-master/

# %%
l= pd.read_html('https://stats.espncricinfo.com/ci/engine/records/averages/batting.html?class=3;id=6;type=team')

# %%
type(l)
# Out:
# list

# %%
len(l)  # 3 tables are present on url
# Out:
# 3

# %%
l[0]
# Out:
#                Player       Span  Mat Inns NO  Runs   HS    Ave   BF      SR  \
# 0          AB Agarkar  2006-2007    4    2  0    15   14   7.50   11  136.36
# 1            KK Ahmed  2018-2019   14    1  1     1   1*      -    1  100.00
# 2           S Aravind  2015-2015    1    -  -     -    -      -    -       -
# 3            R Ashwin  2010-2021   51   11  7   123  31*  30.75  115  106.95
# 4          Avesh Khan  2022-2022    2    -  -     -    -      -    -       -
# ..                ...        ...  ...  ... ..   ...  ...    ...  ...     ...
# 92      R Vinay Kumar  2010-2013    9    1  1     2   2*      -    4   50.00
# 93  Washington Sundar  2017-2021   31   11  4    47  14*   6.71   32  146.87
# 94           SA Yadav  2021-2022   14   12  3   351   65  39.00  212  165.56
# 95           UT Yadav  2012-2019    7    1  0     2    2   2.00    4   50.00
# 96       Yuvraj Singh  2007-2017   58   51  9  1177  77*  28.02  863  136.38
#
#    100 50  0  4s  6s
# 0    0  0  0   2   0
# ...

# %%
l[1]
# Out:
#                                                    0
# 0  By default, the shading indicates records from...
# 1  Adjust:  most recent  | past week  | past mont...

# %%
l[2]
# Out:
#                                                    0
# 0  Records includes the following current or rece...
# 1  India v Sri Lanka at Dharamsala, 3rd T20I, Feb...
# 2  India v Sri Lanka at Dharamsala, 2nd T20I, Feb...
# 3  India v Sri Lanka at Lucknow, 1st T20I, Feb 24...

# %%
l[0] # To store this data see the following cell.
# Out:
#                Player       Span  Mat Inns NO  Runs   HS    Ave   BF      SR  \
# 0          AB Agarkar  2006-2007    4    2  0    15   14   7.50   11  136.36
# 1            KK Ahmed  2018-2019   14    1  1     1   1*      -    1  100.00
# 2           S Aravind  2015-2015    1    -  -     -    -      -    -       -
# 3            R Ashwin  2010-2021   51   11  7   123  31*  30.75  115  106.95
# 4          Avesh Khan  2022-2022    2    -  -     -    -      -    -       -
# ..                ...        ...  ...  ... ..   ...  ...    ...  ...     ...
# 92      R Vinay Kumar  2010-2013    9    1  1     2   2*      -    4   50.00
# 93  Washington Sundar  2017-2021   31   11  4    47  14*   6.71   32  146.87
# 94           SA Yadav  2021-2022   14   12  3   351   65  39.00  212  165.56
# 95           UT Yadav  2012-2019    7    1  0     2    2   2.00    4   50.00
# 96       Yuvraj Singh  2007-2017   58   51  9  1177  77*  28.02  863  136.38
#
#    100 50  0  4s  6s
# 0    0  0  0   2   0
# ...

# %%
l[0].to_csv("Cricket.csv",index=False)

# %%
ls
# Out:
#  MongoDB/
# 1#_iNEURON_PYTHON_4DEC_&_5DEC_2021.ipynb
# 10#_iNEURON_PYTHON_12FEB_&_13FEB_2022.ipynb
# 10.1#_iNEURON_PYTHON_12FEB_&_13FEB_2022.ipynb
# 10.2#_iNEURON_PYTHON_12FEB_&_13FEB_2022.ipynb
# 11#_iNEURON_PYTHON_19FEB_&_20FEB_2022.ipynb
# 12#_iNEURON_PYTHON_26FEB_&_27FEB_2022.ipynb
# 13#_iNEURON_PYTHON_5MAR_&_6MAR_2022.ipynb
# 2#_iNEURON_PYTHON_18DEC_&_19DEC_2021.ipynb
# 3#_iNEURON_PYTHON_20DEC_&_21DEC_2021.ipynb
# 4#_iNEURON_PYTHON_23DEC_2021.ipynb
# 5#_iNEURON_PYTHON_8JAN_&_9JAN_2022.ipynb
# 6#_iNEURON_PYTHON_15JAN_&_16JAN_2022.ipynb
# 7#_iNEURON_PYTHON_22JAN_&_23JAN_2022.ipynb
# 7.1#_iNEURON_PYTHON_22JAN_&_23JAN_2022.ipynb
# 8#_iNEURON_PYTHON_29JAN_&_30JAN_2022.ipynb
# 9#_iNEURON_PYTHON_5FEB_&_6FEB_2022.ipynb
# Cricket.csv
# DATA SET/
# FILES/
# LUSID Excel - Manage Orders.xlsx
# NBA.csv
# NBA.xlsx
# PycharmProjects/
# glass.csv
# glass.data
# google.txt
# ineuron.db
# jobdb.db
# ohana-api-master/
# person.db
# sample-excel-master/

# %%
d ="""{"name" : "Sudhanshu kumar" , 
"email id " : "sskumar@gmail.com",
"tech" : ["ML" , "DL" , "CV" ],
"plateform" : ["techneuron" , "kidsneuron" , "ineuron"]
}"""

# %%
type(d)
# Out:
# str

# %%
import json

# %%
result  = json.loads(d)

# %%
type(result)
# Out:
# dict

# %%
result['name']
# Out:
# 'Sudhanshu kumar'

# %%
# To see the data into a tabuler format.
df=pd.DataFrame(result)
df
# Out:
#               name          email id  tech   plateform
# 0  Sudhanshu kumar  sskumar@gmail.com   ML  techneuron
# 1  Sudhanshu kumar  sskumar@gmail.com   DL  kidsneuron
# 2  Sudhanshu kumar  sskumar@gmail.com   CV     ineuron

# %%
# Now if i want to see only one column in o/p then  
pd.DataFrame(result['name'])

# It is not working because name is string it is not list
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/g0/424mq_gn0jq76h7qlxtqdg_h0000gn/T/ipykernel_11697/3516099768.py in <module>
#       1 # Now if i want to see only one column in o/p then
# ----> 2 pd.DataFrame(result['name'])
#       3
#       4 # It is not working because name is string it is not list
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     728         else:
#     729             if index is None or columns is None:
# --> 730                 raise ValueError("DataFrame constructor not properly called!")
#     731
#     732             # Argument 1 to "ensure_index" has incompatible type "Collection[Any]";
#
# ValueError: DataFrame constructor not properly called!

# %%
df.iloc[:,0]
# Out:
# 0    Sudhanshu kumar
# 1    Sudhanshu kumar
# 2    Sudhanshu kumar
# Name: name, dtype: object

# %%
# It will work because tech is list.

pd.DataFrame(result['tech'])
# Out:
#     0
# 0  ML
# 1  DL
# 2  CV

# %%
 d= {"packetType":"D","data":{"checkEngineLightFlag":"F","batteryVoltageStableTime":0,"batteryVoltageStable":"0","batteryVoltageOff":"12.42","batteryCrankParamTN":"-0.08","batteryCrankParamVN":"0.00","batteryCrankParamTP":"-0.08","batteryCrankParamVP":"0.00","batteryCrankParamTT":"-0.00008","batteryCrankParamV0":"0.00","batteryVoltageMaxOn":"13.05","batteryVoltageMinOn":"12.97","batteryVoltageMaxOff":"12.46","batteryVoltageMinOff":"12.36","batteryVoltageOnAverage":"13.02","engineLoadMax":"84","engineLoadAverage":"39.98","rpmMax":"3487","rpmAverage":"1431.29","gpsSpeedAverage":"21.99","vssMax":"53.44","vssAverage":"23.06","tcuTemperatureMin":"82.40","tcuTemperatureMax":"109.40","tcuTemperatureAverage":"104.87","coolantMin":"158.00","coolantMax":"188.60","coolantAverage":"180.20","packetStartLocal":1508143346000,"tripStartLocal":1508143346000,"milIndicator":"F","monitorsNotReady":0,"imei":"60DF5417","gatewayTs":1515613306592,"diagnosticTroubleCodeData":[],"diagnosticPidData":[[64768,47,100],[64768,1,517376],[64800,1,262144],[64768,5,125]]},"header":{"iwrapVer":"1.9.20","sourceSystem":"CDP","configVer":"1.1","oemName":"HUM","unitType":0,"cpVer":"7.50.1.9","igpsVer":"1.3.7","messageType":"Notification","pomVer":"1.0","headerVer":"V6","timestamp":0,"deviceType":"InDrive","visorVer":"1.4.35","transactionId":"53098471-7787-4160-94b3-cd69dcc70416","deviceSerialNo":"60DF5417","subOrganization":"HUM","organization":"HUM","imei":"60DF5417","operation":"Notification"}}

# %%
type(d)
# Out:
# dict

# %%
pd.DataFrame(d)
# Out:
#                           packetType  \
# checkEngineLightFlag               D
# batteryVoltageStableTime           D
# batteryVoltageStable               D
# batteryVoltageOff                  D
# batteryCrankParamTN                D
# batteryCrankParamVN                D
# batteryCrankParamTP                D
# batteryCrankParamVP                D
# batteryCrankParamTT                D
# batteryCrankParamV0                D
# batteryVoltageMaxOn                D
# batteryVoltageMinOn                D
# batteryVoltageMaxOff               D
# batteryVoltageMinOff               D
# batteryVoltageOnAverage            D
# engineLoadMax                      D
# engineLoadAverage                  D
# rpmMax                             D
# rpmAverage                         D
# gpsSpeedAverage                    D
# vssMax                             D
# vssAverage                         D
# tcuTemperatureMin                  D
# tcuTemperatureMax                  D
# ...

# %%
aa=pd.DataFrame(d)
type(aa)
# Out:
# pandas.core.frame.DataFrame

# %%
pd.DataFrame(d["data"]) # It will show us error.

# see the error and resolve it.

# Here in data ther is one key value pair whoes key is present but value is missing so thats why it shows error.
# 'diagnosticTroubleCodeData':[].
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/g0/424mq_gn0jq76h7qlxtqdg_h0000gn/T/ipykernel_11697/407756433.py in <module>
# ----> 1 pd.DataFrame(d["data"]) # It will show us error.
#       2
#       3 # see the error and resolve it.
#       4
#       5 # Here in data ther is one key value pair whoes key is present but value is missing so thats why it shows error.
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     612         elif isinstance(data, dict):
#     613             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 614             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     615         elif isinstance(data, ma.MaskedArray):
#     616             import numpy.ma.mrecords as mrecords
#
# ...

# %%
d1 = d["data"]

# %%
d1
# Out:
# {'checkEngineLightFlag': 'F',
#  'batteryVoltageStableTime': 0,
#  'batteryVoltageStable': '0',
#  'batteryVoltageOff': '12.42',
#  'batteryCrankParamTN': '-0.08',
#  'batteryCrankParamVN': '0.00',
#  'batteryCrankParamTP': '-0.08',
#  'batteryCrankParamVP': '0.00',
#  'batteryCrankParamTT': '-0.00008',
#  'batteryCrankParamV0': '0.00',
#  'batteryVoltageMaxOn': '13.05',
#  'batteryVoltageMinOn': '12.97',
#  'batteryVoltageMaxOff': '12.46',
#  'batteryVoltageMinOff': '12.36',
#  'batteryVoltageOnAverage': '13.02',
#  'engineLoadMax': '84',
#  'engineLoadAverage': '39.98',
#  'rpmMax': '3487',
#  'rpmAverage': '1431.29',
#  'gpsSpeedAverage': '21.99',
#  'vssMax': '53.44',
#  'vssAverage': '23.06',
#  'tcuTemperatureMin': '82.40',
#  'tcuTemperatureMax': '109.40',
#  'tcuTemperatureAverage': '104.87',
#  'coolantMin': '158.00',
#  'coolantMax': '188.60',
#  'coolantAverage': '180.20',
#  'packetStartLocal': 1508143346000,
#  'tripStartLocal': 1508143346000,
#  'milIndicator': 'F',
# ...

# %%
del d1['diagnosticTroubleCodeData']

# %%
d1
# Out:
# {'checkEngineLightFlag': 'F',
#  'batteryVoltageStableTime': 0,
#  'batteryVoltageStable': '0',
#  'batteryVoltageOff': '12.42',
#  'batteryCrankParamTN': '-0.08',
#  'batteryCrankParamVN': '0.00',
#  'batteryCrankParamTP': '-0.08',
#  'batteryCrankParamVP': '0.00',
#  'batteryCrankParamTT': '-0.00008',
#  'batteryCrankParamV0': '0.00',
#  'batteryVoltageMaxOn': '13.05',
#  'batteryVoltageMinOn': '12.97',
#  'batteryVoltageMaxOff': '12.46',
#  'batteryVoltageMinOff': '12.36',
#  'batteryVoltageOnAverage': '13.02',
#  'engineLoadMax': '84',
#  'engineLoadAverage': '39.98',
#  'rpmMax': '3487',
#  'rpmAverage': '1431.29',
#  'gpsSpeedAverage': '21.99',
#  'vssMax': '53.44',
#  'vssAverage': '23.06',
#  'tcuTemperatureMin': '82.40',
#  'tcuTemperatureMax': '109.40',
#  'tcuTemperatureAverage': '104.87',
#  'coolantMin': '158.00',
#  'coolantMax': '188.60',
#  'coolantAverage': '180.20',
#  'packetStartLocal': 1508143346000,
#  'tripStartLocal': 1508143346000,
#  'milIndicator': 'F',
# ...

# %%
# Now we will not get any kind of error.
pd.DataFrame(d1)
# Out:
#   checkEngineLightFlag  batteryVoltageStableTime batteryVoltageStable  \
# 0                    F                         0                    0
# 1                    F                         0                    0
# 2                    F                         0                    0
# 3                    F                         0                    0
#
#   batteryVoltageOff batteryCrankParamTN batteryCrankParamVN  \
# 0             12.42               -0.08                0.00
# 1             12.42               -0.08                0.00
# 2             12.42               -0.08                0.00
# 3             12.42               -0.08                0.00
#
#   batteryCrankParamTP batteryCrankParamVP batteryCrankParamTT  \
# 0               -0.08                0.00            -0.00008
# 1               -0.08                0.00            -0.00008
# 2               -0.08                0.00            -0.00008
# ...

# %%
# url = "https://api.github.com/repos/pandas-dev/pandas/issues"

pd.read_json("https://api.github.com/repos/pandas-dev/pandas/issues")
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
# Here in above cell we have just read the data. But now we are going to convert data into the table format 
# with help of pandas.

# import requests it is fetching raw data from url into the consol. 
import requests

url = "https://api.github.com/repos/pandas-dev/pandas/issues"

# %%
data = requests.get(url)

# %%
data
# Out:
# <Response [200]>

# %%
data1 = data.json()

# %%
data1
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46799',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46799/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46799/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46799/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/46799',
#   'id': 1207499980,
#   'node_id': 'I_kwDOAA0YD85H-PzM',
#   'number': 46799,
#   'title': 'BUG: Merge fails on nullable integer columns when dtypes are unequal',
#   'user': {'login': 'NickCrews',
#    'id': 10820686,
#    'node_id': 'MDQ6VXNlcjEwODIwNjg2',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10820686?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/NickCrews',
#    'html_url': 'https://github.com/NickCrews',
# ...

# %%
type(data1)
# Out:
# list

# %%
len(data1)
# Out:
# 30

# %%
data1
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46680',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46680/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46680/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46680/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/46680',
#   'id': 1195938132,
#   'node_id': 'I_kwDOAA0YD85HSJFU',
#   'number': 46680,
#   'title': 'ENH: Support Python 3.11',
#   'user': {'login': 'EwoutH',
#    'id': 15776622,
#    'node_id': 'MDQ6VXNlcjE1Nzc2NjIy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/15776622?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/EwoutH',
#    'html_url': 'https://github.com/EwoutH',
#    'followers_url': 'https://api.github.com/users/EwoutH/followers',
# ...

# %%
data1[0]
# Out:
# {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46680',
#  'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#  'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46680/labels{/name}',
#  'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46680/comments',
#  'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46680/events',
#  'html_url': 'https://github.com/pandas-dev/pandas/issues/46680',
#  'id': 1195938132,
#  'node_id': 'I_kwDOAA0YD85HSJFU',
#  'number': 46680,
#  'title': 'ENH: Support Python 3.11',
#  'user': {'login': 'EwoutH',
#   'id': 15776622,
#   'node_id': 'MDQ6VXNlcjE1Nzc2NjIy',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/15776622?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/EwoutH',
#   'html_url': 'https://github.com/EwoutH',
#   'followers_url': 'https://api.github.com/users/EwoutH/followers',
# ...

# %%
data1[0]['user']
# Out:
# {'login': 'EwoutH',
#  'id': 15776622,
#  'node_id': 'MDQ6VXNlcjE1Nzc2NjIy',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/15776622?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/EwoutH',
#  'html_url': 'https://github.com/EwoutH',
#  'followers_url': 'https://api.github.com/users/EwoutH/followers',
#  'following_url': 'https://api.github.com/users/EwoutH/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/EwoutH/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/EwoutH/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/EwoutH/subscriptions',
#  'organizations_url': 'https://api.github.com/users/EwoutH/orgs',
#  'repos_url': 'https://api.github.com/users/EwoutH/repos',
#  'events_url': 'https://api.github.com/users/EwoutH/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/EwoutH/received_events',
#  'type': 'User',
#  'site_admin': False}

# %%
data1[0]['user']['id']
# Out:
# 15776622

# %%
# Take out all ID from the above info.
for i in range(len(data1)):
    print(data1[i]['user']['id'])
# Out:
# 15776622
# 33152706
# 8365180
# 7397844
# 47337188
# 11664259
# 247555
# 1926940
# 11664259
# 4665485
# 4476168
# 66919765
# 12933913
# 5902745
# 23652187
# 72577720
# 102976413
# 12546463
# 5902745
# 28753166
# 41546976
# 4476168
# 15721311
# 6618166
# 1796
# 29204546
# 11664259
# 55816259
# 7670869
# 175722

# %%
data1
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46680',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46680/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46680/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46680/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/46680',
#   'id': 1195938132,
#   'node_id': 'I_kwDOAA0YD85HSJFU',
#   'number': 46680,
#   'title': 'ENH: Support Python 3.11',
#   'user': {'login': 'EwoutH',
#    'id': 15776622,
#    'node_id': 'MDQ6VXNlcjE1Nzc2NjIy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/15776622?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/EwoutH',
#    'html_url': 'https://github.com/EwoutH',
#    'followers_url': 'https://api.github.com/users/EwoutH/followers',
# ...

# %%
# Someone ask us that can you showcase some 'id','url','repository_url','labels_url','user' in tabuler 
# format.

# %%
df2 = pd.DataFrame(data1,columns=['id','url','repository_url','labels_url','user'])

# %%
df2.to_csv('json_res.csv')

# %%
ls
# Out:
#  MongoDB/
# 1#_iNEURON_PYTHON_4DEC_&_5DEC_2021.ipynb
# 10#_iNEURON_PYTHON_12FEB_&_13FEB_2022.ipynb
# 10.1#_iNEURON_PYTHON_12FEB_&_13FEB_2022.ipynb
# 10.2#_iNEURON_PYTHON_12FEB_&_13FEB_2022.ipynb
# 11#_iNEURON_PYTHON_19FEB_&_20FEB_2022.ipynb
# 12#_iNEURON_PYTHON_26FEB_&_27FEB_2022.ipynb
# 13#_iNEURON_PYTHON_5MAR_&_6MAR_2022.ipynb
# 2#_iNEURON_PYTHON_18DEC_&_19DEC_2021.ipynb
# 3#_iNEURON_PYTHON_20DEC_&_21DEC_2021.ipynb
# 4#_iNEURON_PYTHON_23DEC_2021.ipynb
# 5#_iNEURON_PYTHON_8JAN_&_9JAN_2022.ipynb
# 6#_iNEURON_PYTHON_15JAN_&_16JAN_2022.ipynb
# 7#_iNEURON_PYTHON_22JAN_&_23JAN_2022.ipynb
# 7.1#_iNEURON_PYTHON_22JAN_&_23JAN_2022.ipynb
# 8#_iNEURON_PYTHON_29JAN_&_30JAN_2022.ipynb
# 9#_iNEURON_PYTHON_5FEB_&_6FEB_2022.ipynb
# Cricket.csv
# DATA SET/
# FILES/
# LUSID Excel - Manage Orders.xlsx
# NBA.csv
# NBA.xlsx
# PycharmProjects/
# glass.csv
# glass.data
# google.txt
# ineuron.db
# jobdb.db
# json_res.csv
# ohana-api-master/
# person.db
# sample-excel-master/

# %%
df3=pd.read_csv('json_res.csv')
df3
# Out:
#     Unnamed: 0          id                                                url  \
# 0            0  1195938132  https://api.github.com/repos/pandas-dev/pandas...
# 1            1  1195898433  https://api.github.com/repos/pandas-dev/pandas...
# 2            2  1195647067  https://api.github.com/repos/pandas-dev/pandas...
# 3            3  1195360374  https://api.github.com/repos/pandas-dev/pandas...
# 4            4  1195346688  https://api.github.com/repos/pandas-dev/pandas...
# 5            5  1195223008  https://api.github.com/repos/pandas-dev/pandas...
# 6            6  1195155832  https://api.github.com/repos/pandas-dev/pandas...
# 7            7  1195110557  https://api.github.com/repos/pandas-dev/pandas...
# 8            8  1195097357  https://api.github.com/repos/pandas-dev/pandas...
# 9            9  1194959471  https://api.github.com/repos/pandas-dev/pandas...
# 10          10  1194890511  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
df8 = pd.DataFrame(data1)
df8
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
import json
df9 = pd.json_normalize(df8['user'])
# Out:
#                  login         id               node_id  \
# 0               EwoutH   15776622  MDQ6VXNlcjE1Nzc2NjIy
# 1             laohu123   33152706  MDQ6VXNlcjMzMTUyNzA2
# 2              ZHANGGU    8365180  MDQ6VXNlcjgzNjUxODA=
# 3                YunJD    7397844  MDQ6VXNlcjczOTc4NDQ=
# 4   xinrong-databricks   47337188  MDQ6VXNlcjQ3MzM3MTg4
# 5        galipremsagar   11664259  MDQ6VXNlcjExNjY0MjU5
# 6               tswast     247555  MDQ6VXNlcjI0NzU1NQ==
# 7             jgmarcel    1926940  MDQ6VXNlcjE5MjY5NDA=
# 8        galipremsagar   11664259  MDQ6VXNlcjExNjY0MjU5
# 9          WillianFuks    4665485  MDQ6VXNlcjQ2NjU0ODU=
# 10              kwhkim    4476168  MDQ6VXNlcjQ0NzYxNjg=
# 11              Kyrpel   66919765  MDQ6VXNlcjY2OTE5NzY1
# 12           helgehatt   12933913  MDQ6VXNlcjEyOTMzOTEz
# 13    johannes-mueller    5902745  MDQ6VXNlcjU5MDI3NDU=
# 14     SteffenMeinecke   23652187  MDQ6VXNlcjIzNjUyMTg3
# 15   MichaelTiemannOSC   72577720  MDQ6VXNlcjcyNTc3NzIw
# ...

# %% [markdown]
# #  5th MAR

# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
df.tail(4)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.info() 

# look at the data carefully in all column there are two columns i.e. 'AGE' and 'CABIN' has less no. of count.
# It means there are some null values.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.dtypes == "object"
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
type(df.dtypes)
# As we get datatype as "series" it means whatever the operations we can perform with list same we can perfrom 
# with "series".
# Out:
# pandas.core.series.Series

# %%
col_name = df.dtypes[df.dtypes == "object"].index # Here we extract an object where datatype is categorical

# %%
col_name
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
df[col_name]
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %%
df[col_name].describe()
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# If we want to add any column then..
df['ineuron'] = "sudh"

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# If we want name of 1st 15 person from data set. 
df['Name'][0:15]
# Out:
# 0                               Braund, Mr. Owen Harris
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                Heikkinen, Miss. Laina
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                              Allen, Mr. William Henry
# 5                                      Moran, Mr. James
# 6                               McCarthy, Mr. Timothy J
# 7                        Palsson, Master. Gosta Leonard
# 8     Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                   Nasser, Mrs. Nicholas (Adele Achem)
# 10                      Sandstrom, Miss. Marguerite Rut
# 11                             Bonnell, Miss. Elizabeth
# 12                       Saundercock, Mr. William Henry
# 13                          Andersson, Mr. Anders Johan
# 14                 Vestrom, Miss. Hulda Amanda Adolfina
# Name: Name, dtype: object

# %%
df['Name'][0:15:2] # Here we fetch the record with step size of 2.
# Out:
# 0                               Braund, Mr. Owen Harris
# 2                                Heikkinen, Miss. Laina
# 4                              Allen, Mr. William Henry
# 6                               McCarthy, Mr. Timothy J
# 8     Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 10                      Sandstrom, Miss. Marguerite Rut
# 12                       Saundercock, Mr. William Henry
# 14                 Vestrom, Miss. Hulda Amanda Adolfina
# Name: Name, dtype: object

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
import numpy as np

# %%
df['Age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
df['Age'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888     True
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool

# %%
# Tell me the indexes of null value in age column using numpy.

np.where(df['Age'].isnull() == True)

# OR
# Out:
# (array([  5,  17,  19,  26,  28,  29,  31,  32,  36,  42,  45,  46,  47,
#          48,  55,  64,  65,  76,  77,  82,  87,  95, 101, 107, 109, 121,
#         126, 128, 140, 154, 158, 159, 166, 168, 176, 180, 181, 185, 186,
#         196, 198, 201, 214, 223, 229, 235, 240, 241, 250, 256, 260, 264,
#         270, 274, 277, 284, 295, 298, 300, 301, 303, 304, 306, 324, 330,
#         334, 335, 347, 351, 354, 358, 359, 364, 367, 368, 375, 384, 388,
#         409, 410, 411, 413, 415, 420, 425, 428, 431, 444, 451, 454, 457,
#         459, 464, 466, 468, 470, 475, 481, 485, 490, 495, 497, 502, 507,
#         511, 517, 522, 524, 527, 531, 533, 538, 547, 552, 557, 560, 563,
#         564, 568, 573, 578, 584, 589, 593, 596, 598, 601, 602, 611, 612,
#         613, 629, 633, 639, 643, 648, 650, 653, 656, 667, 669, 674, 680,
#         692, 697, 709, 711, 718, 727, 732, 738, 739, 740, 760, 766, 768,
#         773, 776, 778, 783, 790, 792, 793, 815, 825, 826, 828, 832, 837,
# ...

# %%
# Tell me the indexes of null value in age column using pandas.

ind = df[df['Age'].isnull() == True].index
ind
# Out:
# Int64Index([  5,  17,  19,  26,  28,  29,  31,  32,  36,  42,
#             ...
#             832, 837, 839, 846, 849, 859, 863, 868, 878, 888],
#            dtype='int64', length=177)

# %%
# Count of null in age column.
len(ind)
# Out:
# 177

# %%
# Tell me the detail of all column where age=null.

# for this use "loc" it means location and "iloc" it means integer location.

df.loc[ind]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
# Tell me the person name who has paid highest Fare.

# %%
df['Fare']
# Out:
# 0       7.2500
# 1      71.2833
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 886    13.0000
# 887    30.0000
# 888    23.4500
# 889    30.0000
# 890     7.7500
# Name: Fare, Length: 891, dtype: float64

# %%
max(df['Fare'])
# Out:
# 512.3292

# %%
a=df[df['Fare']==max(df['Fare'])]
a
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C

# %%
a=df[df['Fare']==max(df['Fare'])][['Name']]
a
# Out:
#                                    Name
# 258                    Ward, Miss. Anna
# 679  Cardeza, Mr. Thomas Drake Martinez
# 737              Lesurer, Mr. Gustave J

# %%
# Tell me the detail of all column where Cabin=null.

# %%
#df.iloc[np.where(df['Cabin'].isnull()==True)]  -----> Using numpy.

df.iloc[df[df['Cabin'].isnull()==True].index] # ----->Usinf Pandas.
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 2              3         1       3                    Heikkinen, Miss. Laina
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
df.iloc[np.where(df['Cabin'].isnull()==True)][["Age","Name","Cabin"]]
# Out:
#       Age                                      Name Cabin
# 0    22.0                   Braund, Mr. Owen Harris   NaN
# 2    26.0                    Heikkinen, Miss. Laina   NaN
# 4    35.0                  Allen, Mr. William Henry   NaN
# 5     NaN                          Moran, Mr. James   NaN
# 7     2.0            Palsson, Master. Gosta Leonard   NaN
# ..    ...                                       ...   ...
# 884  25.0                    Sutehall, Mr. Henry Jr   NaN
# 885  39.0      Rice, Mrs. William (Margaret Norton)   NaN
# 886  27.0                     Montvila, Rev. Juozas   NaN
# 888   NaN  Johnston, Miss. Catherine Helen "Carrie"   NaN
# 890  32.0                       Dooley, Mr. Patrick   NaN
#
# [687 rows x 3 columns]

# %%
# Explaination of this task is given in 6th MAR 2022 lecture.

# %%
# Questions

1   . Find out how many male and female passenger was onboarded.
2   . how many survived we have.
3   . how many casuality we have.
4   . what is name of a person who is the eldest one . 
5   . how many passenger do we have in first , second and third class.
6   . how many person we have whose name starts with "s".
7   . try to create a new column which is a summation  of "SibSp" and "parch".
8   . how many person do we have below age of 25.
9   . how many person died whose age was less then 40.
9.1 . How many persons are Survived having sex equal to male.
10  . from a  cabin column seperate text and numeric value.

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# 1.  Find out how many male and female passenger was onboarded.

c=df[df['Sex']=='male']
len(c)

d=df[df['Sex']=='female']
len(d)

e=len(c)+len(d)
e

print(len(c))
print(len(d))

print(e)

# OR see in following cell.
# Out:
# 577
# 314
# 891

# %%
df['Sex'].value_counts()

# OR see in following cell.
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
df.groupby('Sex')['Sex'].count()
# Out:
# Sex
# female    314
# male      577
# Name: Sex, dtype: int64

# %%
# 2. how many survived we have.

s=df[df['Survived']==1]
len(s)
# Out:
# 342

# %%
# 3. how many casuality we have.

c=df[df['Survived']==0]
len(c)
# Out:
# 549

# %%
# 4. what is name of a person who is the eldest one.

a=df[df['Age']==max(df['Age'])][['Name','Age']]
a
# Out:
#                                      Name   Age
# 630  Barkworth, Mr. Algernon Henry Wilson  80.0

# %%
# 5. how many passenger do we have in first,second and third class.

df['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
# 6. how many person we have whose name starts with "s". (IMP)

len(df[df['Name'].str.startswith("S")]['Name'])
# Out:
# 86

# %%
# 7. Try to create a new column which is a summation  of "SibSp" and "parch".

df['New'] = df['SibSp'] + df['Parch']
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# 8. how many person do we have below age of 25.

len(df[df['Age'] < 25])
# Out:
# 278

# %%
# 9. how many person died whose age was less then 40.

len(df[(df['Survived'] == 0 ) & (df["Age"] < 40)])
# Out:
# 322

# %%
# 9.1 How many persons are Survived having sex equal to male.

len(df[(df['Survived'] == 0 ) & (df["Sex"]=='male')])
# Out:
# 468

# %%
# 10. from a cabin column seperate text and numeric value.

import re

replace = re.compile("([a-zA-Z]+)")

df['string_cabin_list'] = df['Cabin'].str.extract(replace)
df['num_cabin_list'] = df['Cabin'].str.replace(replace, "")

# %%
df['string_cabin_list']
# Out:
# 0      NaN
# 1        C
# 2      NaN
# 3        C
# 4      NaN
#       ...
# 886    NaN
# 887      B
# 888    NaN
# 889      C
# 890    NaN
# Name: string_cabin_list, Length: 891, dtype: object

# %%
df['num_cabin_list']
# Out:
# 0      NaN
# 1       85
# 2      NaN
# 3      123
# 4      NaN
#       ...
# 886    NaN
# 887     42
# 888    NaN
# 889    148
# 890    NaN
# Name: num_cabin_list, Length: 891, dtype: object

# %%
# OR see in following cell.

# %%
df2 = pd.DataFrame(df.Cabin.str.split('([a-zA-Z]+)([^a-zA-Z]+)'))
df2
# Out:
#             Cabin
# 0             NaN
# 1     [, C, 85, ]
# 2             NaN
# 3    [, C, 123, ]
# 4             NaN
# ..            ...
# 886           NaN
# 887   [, B, 42, ]
# 888           NaN
# 889  [, C, 148, ]
# 890           NaN
#
# [891 rows x 1 columns]

# %%
# NEW DATASET

# %%
df4 =pd.read_csv('bank.csv',sep=";")
df4
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
df4.head()
# Out:
#    age          job  marital  education default  balance housing loan  \
# 0   30   unemployed  married    primary      no     1787      no   no
# 1   33     services  married  secondary      no     4789     yes  yes
# 2   35   management   single   tertiary      no     1350     yes   no
# 3   30   management  married   tertiary      no     1476     yes  yes
# 4   59  blue-collar  married  secondary      no        0     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# 1  cellular   11   may       220         1    339         4  failure  no
# 2  cellular   16   apr       185         1    330         1  failure  no
# 3   unknown    3   jun       199         4     -1         0  unknown  no
# 4   unknown    5   may       226         1     -1         0  unknown  no

# %%
# Questions

1 . how many campaign available in this dataset . 
2 . how many users do we have with housing and personal loan . 
3 . how many person do we have whose age is 60+ . 
4 . in which month we have trageted most of the customer . 
5 . which mode of call is giving you more result
6 . how many enterpeures do we have in this list  
7 . how many customers do we have with negative balance 
8 . prepare a group of data based on education level . 

https://codeshare.io/X8PY8Y

# %%
# 1. How many campaign available in this dataset. 

len(df4['campaign'].unique())

# Or see in the next cell.
# Out:
# 32

# %%
a1=set(list(df4['campaign']))
len(a1)
# Out:
# 32

# %%
# 2. How many users do we have with housing and personal loan. 

df9 = (df4[(df4['housing'] == 'yes') & (df4['loan'] == 'yes')])
len(df9)

# negation

# df9 = (df4[(df4['housing'] != 'yes') & (df4['loan'] != 'yes')])
# len(df9)
# Out:
# 406

# %%
# 3. How many person do we have whose age is 60+. 

len(df4[df4['age'] >60])
# Out:
# 127

# %%
# 4. In which month we have trageted most of the customer. 

df4["month"].value_counts()
df4["month"].value_counts().index[0]
# Out:
# 'may'

# %%
# 5. Which mode of call is giving you more result as y.  (IMP)

df_groupby = df4.groupby(['contact','y']).count()
df_groupby
# Out:
#                 age   job  marital  education  default  balance  housing  \
# contact   y
# cellular  no   2480  2480     2480       2480     2480     2480     2480
#           yes   416   416      416        416      416      416      416
# telephone no    257   257      257        257      257      257      257
#           yes    44    44       44         44       44       44       44
# unknown   no   1263  1263     1263       1263     1263     1263     1263
#           yes    61    61       61         61       61       61       61
#
#                loan   day  month  duration  campaign  pdays  previous  \
# contact   y
# cellular  no   2480  2480   2480      2480      2480   2480      2480
#           yes   416   416    416       416       416    416       416
# telephone no    257   257    257       257       257    257       257
#           yes    44    44     44        44        44     44        44
# unknown   no   1263  1263   1263      1263      1263   1263      1263
# ...

# %%
df_groupby.loc['telephone','yes'][0]
# Out:
# 44

# %%
df_groupby.loc['unknown','yes'][0]
# Out:
# 61

# %%
df_groupby.loc['cellular','yes'][0]
# Out:
# 416

# %%
max(df_groupby.loc['telephone','yes'][0],df_groupby.loc['unknown','yes'][0],df_groupby.loc['cellular','yes'][0])
# Out:
# 416

# %%
# 6. How many enterpeures do we have in this list. 

g=df4[df4['job'] == 'entrepreneur']
len(g)
# Out:
# 168

# %%
# 7. How many customers do we have with negative balance.

len(df4[df4['balance'] < 0 ])
# Out:
# 366

# %%
# 8. Prepare a group of data based on education level. (IMP)

l = []
for i in df4['education'].unique() : 
    l.append(df4[df4["education"]  == i])
# Out:
#       age            job   marital education default  balance housing loan  \
# 0      30     unemployed   married   primary      no     1787      no   no
# 9      43       services   married   primary      no      -88     yes  yes
# 18     25    blue-collar    single   primary      no     -221     yes   no
# 26     55    blue-collar   married   primary      no      627     yes   no
# 36     78        retired  divorced   primary      no      229      no   no
# ...   ...            ...       ...       ...     ...      ...     ...  ...
# 4480   23    blue-collar   married   primary      no     1158     yes   no
# 4485   53    blue-collar   married   primary      no      238     yes   no
# 4486   37    blue-collar   married   primary      no      378     yes   no
# 4499   45    blue-collar  divorced   primary      no      942      no   no
# 4503   60  self-employed   married   primary      no      362      no  yes
#
# ...

# %%
len(l)
# Out:
# 4

# %%
l[0]
# Out:
#       age            job   marital education default  balance housing loan  \
# 0      30     unemployed   married   primary      no     1787      no   no
# 9      43       services   married   primary      no      -88     yes  yes
# 18     25    blue-collar    single   primary      no     -221     yes   no
# 26     55    blue-collar   married   primary      no      627     yes   no
# 36     78        retired  divorced   primary      no      229      no   no
# ...   ...            ...       ...       ...     ...      ...     ...  ...
# 4480   23    blue-collar   married   primary      no     1158     yes   no
# 4485   53    blue-collar   married   primary      no      238     yes   no
# 4486   37    blue-collar   married   primary      no      378     yes   no
# 4499   45    blue-collar  divorced   primary      no      942      no   no
# 4503   60  self-employed   married   primary      no      362      no  yes
#
# ...

# %%
l[1]
# Out:
#       age          job  marital  education default  balance housing loan  \
# 1      33     services  married  secondary      no     4789     yes  yes
# 4      59  blue-collar  married  secondary      no        0     yes   no
# 7      39   technician  married  secondary      no      147     yes   no
# 10     39     services  married  secondary      no     9374     yes   no
# 11     43       admin.  married  secondary      no      264     yes   no
# ...   ...          ...      ...        ...     ...      ...     ...  ...
# 4514   38  blue-collar  married  secondary      no     1205     yes   no
# 4515   32     services   single  secondary      no      473     yes   no
# 4516   33     services  married  secondary      no     -333     yes   no
# 4518   57   technician  married  secondary      no      295      no   no
# 4519   28  blue-collar  married  secondary      no     1137      no   no
#
#        contact  day month  duration  campaign  pdays  previous poutcome   y
# ...

# %%
l[2]
# Out:
#       age            job   marital education default  balance housing loan  \
# 2      35     management    single  tertiary      no     1350     yes   no
# 3      30     management   married  tertiary      no     1476     yes  yes
# 5      35     management    single  tertiary      no      747      no   no
# 6      36  self-employed   married  tertiary      no      307     yes   no
# 8      41   entrepreneur   married  tertiary      no      221     yes   no
# ...   ...            ...       ...       ...     ...      ...     ...  ...
# 4501   34     management   married  tertiary      no      297     yes   no
# 4506   42     unemployed  divorced  tertiary      no     -166      no   no
# 4509   51     technician   married  tertiary      no     2506      no   no
# 4517   57  self-employed   married  tertiary     yes    -3313     yes  yes
# 4520   44   entrepreneur    single  tertiary      no     1136     yes  yes
#
# ...

# %%
l[3]
# Out:
#       age          job   marital education default  balance housing loan  \
# 20     38   management  divorced   unknown      no        0     yes   no
# 27     67      retired   married   unknown      no      696      no   no
# 49     61       admin.   married   unknown      no     4629     yes   no
# 132    43  blue-collar   married   unknown     yes     -715     yes   no
# 133    48       admin.   married   unknown      no        0     yes   no
# ...   ...          ...       ...       ...     ...      ...     ...  ...
# 4337   73      retired   married   unknown      no      519      no   no
# 4342   50  blue-collar   married   unknown      no     2284     yes   no
# 4428   48  blue-collar   married   unknown      no      439     yes   no
# 4471   59   management   married   unknown      no     3534      no   no
# 4508   42       admin.   married   unknown      no      642     yes  yes
#
#         contact  day month  duration  campaign  pdays  previous poutcome    y
# ...
