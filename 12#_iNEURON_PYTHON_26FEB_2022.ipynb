# %%
# 26th Feb

# %%
# CASSANDRA

# %%
# To do work on Cassandra without python then follow the following steps.
# SEE installation video.
# https://www.youtube.com/watch?v=1a7jBT7YOAE

# %%
pip install cassandra-driver
# Out:
# ...
#      |████████████████████████████████| 4.0 MB 1.5 MB/s eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install cassandra-driver

# %%
# https://astra.datastax.com/org/a14bb3a4-5e92-416e-aafb-c2e75389f925/database/0900790e-33f8-440f-8dad-4591714ca03b/connect
# follow the steps given in this link.

# %%
import cassandra
print( cassandra.__version__)
# Out:
# 3.25.0

# %%
#FOR CONNECTING TO CLOUD SYSTEM
from cassandra.cluster import Cluster
from cassandra.auth import PlainTextAuthProvider

cloud_config= {
        'secure_connect_bundle': '/Users/aniketsatishjoshi/Downloads/secure-connect-aniketj'
}
auth_provider = PlainTextAuthProvider('ZGsiRFPRmgetFTMzHPfdyGkN', 'IsPBLl-,oRP9UrzjWRZrAcssGNR2xhQmWs9LbU62MypHDj2zbwOSnwGSzPJNIIPaiHZJnMRGzcZSdB,gh2OfcsMvjE3dsAs3DXzuZuk8X.BlKXG0hMmdgH2zfzQ+g,Qw')
cluster = Cluster(cloud=cloud_config, auth_provider=auth_provider)
session = cluster.connect()

row = session.execute("select release_version from system.local").one()
if row:
    print(row[0])
else:
    print("An error occurred.")
    
# Here we are getting error while copying the path i.e. in line no.6
# Out:
# ---------------------------------------------------------------------------
# IsADirectoryError                         Traceback (most recent call last)
# /var/folders/g0/424mq_gn0jq76h7qlxtqdg_h0000gn/T/ipykernel_4927/844466276.py in <module>
#       6 }
#       7 auth_provider = PlainTextAuthProvider('ZGsiRFPRmgetFTMzHPfdyGkN', 'IsPBLl-,oRP9UrzjWRZrAcssGNR2xhQmWs9LbU62MypHDj2zbwOSnwGSzPJNIIPaiHZJnMRGzcZSdB,gh2OfcsMvjE3dsAs3DXzuZuk8X.BlKXG0hMmdgH2zfzQ+g,Qw')
# ----> 8 cluster = Cluster(cloud=cloud_config, auth_provider=auth_provider)
#       9 session = cluster.connect()
#      10
#
# /opt/anaconda3/lib/python3.7/site-packages/cassandra/cluster.cpython-37m-darwin.so in cassandra.cluster.Cluster.__init__()
#
# /opt/anaconda3/lib/python3.7/site-packages/cassandra/datastax/cloud/__init__.py in get_cloud_config(cloud_config, create_pyopenssl_context)
#      86
#      87     try:
# ---> 88         config = read_cloud_config_from_zip(cloud_config, create_pyopenssl_context)
# ...

# %%
# FOR CONNECTING TO LOCAL SYSYTEM
from cassandra.cluster import Cluster
#from cassandra.auth import PlainTextAuthProvider

#cloud_config= {'secure_connect_bundle':r'C:\Users\Admin\Downloads\secure-connect-test.zip'}
#auth_provider = PlainTextAuthProvider('xbCLnGiTgbFemYjnNKyXmdJk', 'uZQFsScneNQ8+WhqNmLehyRXNZ4HZ233ktFIw1fkCulK,czUQ7hGkJJze4lzHU2Mcl7vOMm56,7sQJYiFLIUwQzjw4BEeWufXeaMC8vG1exmzGaoQ+glmBLW8+48tIAd')
cluster = Cluster()
session = cluster.connect()

row = session.execute("select release_version from system.local")
print(row)

# Here we are getting error while connecting the python.
# Out:
# ---------------------------------------------------------------------------
# NoHostAvailable                           Traceback (most recent call last)
# /var/folders/g0/424mq_gn0jq76h7qlxtqdg_h0000gn/T/ipykernel_4927/2106972409.py in <module>
#       6 #auth_provider = PlainTextAuthProvider('xbCLnGiTgbFemYjnNKyXmdJk', 'uZQFsScneNQ8+WhqNmLehyRXNZ4HZ233ktFIw1fkCulK,czUQ7hGkJJze4lzHU2Mcl7vOMm56,7sQJYiFLIUwQzjw4BEeWufXeaMC8vG1exmzGaoQ+glmBLW8+48tIAd')
#       7 cluster = Cluster()
# ----> 8 session = cluster.connect()
#       9
#      10 row = session.execute("select release_version from system.local")
#
# /opt/anaconda3/lib/python3.7/site-packages/cassandra/cluster.cpython-37m-darwin.so in cassandra.cluster.Cluster.connect()
#
# /opt/anaconda3/lib/python3.7/site-packages/cassandra/cluster.cpython-37m-darwin.so in cassandra.cluster.Cluster.connect()
#
# /opt/anaconda3/lib/python3.7/site-packages/cassandra/cluster.cpython-37m-darwin.so in cassandra.cluster.Cluster.connect()
#
# ...

# %%
# create keyspace in database
row = session.execute("CREATE KEYSPACE home WITH replication = {'class': 'SimpleStrategy', 'replication_factor' : 4};")

# %%
#use keyspace
row=session.execute("use home;")

# %%
# alter keyspace
row=session.execute("ALTER KEYSPACE home WITH replication = {'class': 'SimpleStrategy', 'replication_factor' : 3};")

# %%
#dropping the keyspace
row=session.execute("DROP KEYSPACE home;")

# %%
try:
    row=session.execute("use home;")
except Exception as e:
    print(e)

# %%
row = session.execute("CREATE KEYSPACE home WITH replication = {'class': 'SimpleStrategy', 'replication_factor' : 4};")

# %%
#creating table in the keyspace
row=session.execute("CREATE TABLE Members(id int PRIMARY KEY,name text,age int,height int);")

# %%
#inserting into table
row=session.execute("INSERT INTO Members(id,name,age,height) VALUES (1,'mohit',25,160);")

# %%
row=session.execute("INSERT INTO Members(id,name,age,height) VALUES (2,'shubham',26,165);")
row=session.execute("INSERT INTO Members(id,name,age,height) VALUES (3,'aradhana',25,142);")
row=session.execute("INSERT INTO Members(id,name,age,height) VALUES (4,'rakesh',55,157);")
row=session.execute("INSERT INTO Members(id,name,age,height) VALUES (5,'poonam',52,145);")
row=session.execute("INSERT INTO Members(id,name,age,height) VALUES (6,'seema',30,145);")

# %%
#view the data in table
row=session.execute("select * from Members;")
for i in row:
    print(i)

# %%
#not inserting value in some column
row=session.execute("INSERT INTO Members(id,name,age) VALUES (9,'sakshi',32);")

# %%
#view the data in table 
row=session.execute("select * from Members;")
for i in row:
    print(i)
#null where data not given

# %%
#alter existing table (adding more columns to table)
row=session.execute("ALTER TABLE Members ADD email varchar;")

# %%
row=session.execute("select * from Members;")
for i in row:
    print(i)

# %%
#dropping the table
row=session.execute("DROP TABLE if exists Member;")

# %%
#truncating (removing all data from table)
row=session.execute("TRUNCATE Members;")

# %%
#table is empty now
for i in row:
    print(i)

# %%
#INSERING DATA 
row=session.execute("INSERT INTO Members(id,name,age,height,email) VALUES (2,'shubham',26,165,'memohit@gmail.com');")
row=session.execute("INSERT INTO Members(id,name,age,height) VALUES (3,'aradhana',25,142);")
row=session.execute("INSERT INTO Members(id,name,age,height) VALUES (4,'rakesh',55,157);")
row=session.execute("INSERT INTO Members(id,name,age,height) VALUES (5,'poonam',52,145);")
row=session.execute("INSERT INTO Members(id,name,age,height) VALUES (6,'seema',30,145);")

# %%
#update existing table 
row=session.execute("UPDATE home.Members SET name= 'Mohit Raghav',age = 28 WHERE id=1;")

# %%
#view the data in table 
row=session.execute("select * from Members;")
for i in row:
    print(i)

# %%
#delete a particular row or a part of row
row=session.execute("DELETE age FROM Members WHERE id=3;")

# %%
#view the data in table 
row=session.execute("select * from Members;")
for i in row:
    print(i)

# %%
#selecting particular data
row=session.execute("SELECT name, age FROM Members WHERE id = 1;")

# %%
for i in row:
    print(i)

# %%
# Cassandra DB operation
# http://localhost:8888/notebooks/Downloads/casandra%20(%20Previous%20Batch%20recording%20)/Cassandra%20DB%20operation.ipynb

# %%
session.execute("create table ineuro.emp(emp_id int PRIMARY KEY,emp_name int);")

# %%
session.execute("insert into ineuro.emp(emp_id ,emp_name) values(333,589);")

# %% [markdown]
# Select all data from a table

# %%
ss= session.execute("select * from  ineuro.emp  ;")
for i in ss:
    print(i[0],i[1],i[2],i[3])

# %%
ss= session.prepare("select * from  ineuro.emp where emp_id = ? ;")

res= session.execute(ss,[1])
for i in res:
    print(i[0],'|',i[1],'|',i[2],'|',i[3])

# %% [markdown]
# Insert a row into Emp

# %%
session.execute("INSERT INTO ineuro.emp (emp_id,doj,ename,sal) values (%s,%s,%s,%s)",[4,'2019-07-01','debasish',1234])

# %%
ss= session.execute("select * from  ineuro.emp  ;")
for i in ss:
    print(i[0],i[1],i[2],i[3])

# %% [markdown]
# Update a record in Emp

# %%
prepare_st= "update ineuro.emp SET sal= ?,ename= ? where emp_id= ? ;"
prepare_ud= session.prepare(prepare_st)
session.execute(prepare_ud,[2222,'SUDH',1])

# %%
ss= session.execute("select * from  ineuro.emp  ;")
for i in ss:
    print(i[0],i[1],i[2],i[3])

# %% [markdown]
# insert Multiple Records to DB

# %%
from cassandra.query import BatchStatement

qr1= "insert into ineuro.emp (emp_id,doj,ename,sal) values(%s,%s,%s,%s)"
batch = BatchStatement()
batch.add(qr1,[5,'2018-12-25 01:12:30','Vishnu',2000])
batch.add(qr1,[6,'2019-05-12 02:10:30','Harish',1800])
batch.add(qr1,[7,'2020-01-22 11:10:30','Rahul',5000])
session.execute(batch)
print('Insert completed')

# %% [markdown]
# Delete a record from EMP¶

# %%
dt_rec= "delete from ineuro.emp where emp_id= ?;"
dt_st= session.prepare(dt_rec)
session.execute(dt_st,[6])
print('Record deleted successfully...')

# %% [markdown]
# Insert data from a CSV file to Cassandra DB¶

# %%
import csv
with open('cric.csv','r') as data:
    next(data)
    data_csv= csv.reader(data,delimiter=',')
    #csv reader object
    print(data_csv)
    all_value= []
    for i in data_csv:
        session.execute("insert into ineuro.dataa (idd,first_name,last_name) values(%s,%s,%s)",[int(i[0]),i[1],i[2]])
print('Finished')

# %% [markdown]
# # PANDAS

# %%
import pandas as pd  # pandas as pd it just an alias  we can write import pandas as ani also.

# and then...

# ani.read_csv('/Users/aniketsatishjoshi/Downloads/ohana-api-master/data/sample-csv/addresses.csv')

# %%
# If we write pd.re <--- this and press 'tab' then we will get many options that how many different kind of 
# files pnadas can read.

# Reading operation of any kind of file.
# 1st start with CSV.

pd.read_csv('/Users/aniketsatishjoshi/Downloads/ohana-api-master/data/sample-csv/addresses.csv')
# Out:
#     id  location_id                   address_1  address_2  \
# 0    1            1       2600 Middlefield Road        NaN
# 1    2            2            24 Second Avenue        NaN
# 2    3            3            24 Second Avenue        NaN
# 3    4            4            24 Second Avenue        NaN
# 4    5            5            24 Second Avenue        NaN
# 5    6            6           800 Middle Avenue        NaN
# 6    7            7              500 Arbor Road        NaN
# 7    8            8           800 Middle Avenue        NaN
# 8    9            9       2510 Middlefield Road        NaN
# 9   10           10       1044 Middlefield Road        NaN
# 10  11           11         2140 Euclid Avenue.        NaN
# 11  12           12       1044 Middlefield Road  2nd Floor
# 12  13           13         399 Marine Parkway.        NaN
# 13  14           14          660 Veterans Blvd.        NaN
# 14  15           15        1500 Valencia Street        NaN
# ...

# %%
pd.read_csv('/Users/aniketsatishjoshi/Downloads/ohana-api-master/data/sample-csv/addresses.csv')

# %%
# If you are using windows then put r' while giving path of file in bracket.i.e.
#                            |
#                            |
#                            V
# pd.read_csv(r'/Users/aniketsatishjoshi/Downloads/ohana-api-master/data/sample-csv/addresses.csv')

# %%
# Remember one thing that if we try to import csv or excel file into notebook so pandas will take 1st row of 
# that file as column name in notebook and it will asign row indexes start from 0. see file and here below

df=pd.read_csv('/Users/aniketsatishjoshi/Downloads/ohana-api-master/data/sample-csv/locations.csv')
df
# Out:
#     id  organization_id                                      accessibility  \
# 0    1                1       disabled_parking, ramp, restroom, wheelchair
# 1    2                1                                         wheelchair
# 2    3                1                                                NaN
# 3    4                1                                         wheelchair
# 4    5                1                                         wheelchair
# 5    6                2                       disabled_parking, wheelchair
# 6    7                2       ramp, restroom, disabled_parking, wheelchair
# 7    8                2                                                NaN
# 8    9                3                         ramp, restroom, wheelchair
# 9   10                3  elevator, tape_braille, ramp, restroom, disabl...
# 10  11                3                                               ramp
# ...

# %%
# Now if we do this header = none then 
df=pd.read_csv('/Users/aniketsatishjoshi/Downloads/ohana-api-master/data/sample-csv/locations.csv',header=None)
df

# Now see the table minutely here header(column name) is get removed from table and add as row inside the table.
# It will give column name as 0,1,2,3....etc.
# Out:
#     0                1                                                  2   \
# 0   id  organization_id                                      accessibility
# 1    1                1       disabled_parking, ramp, restroom, wheelchair
# 2    2                1                                         wheelchair
# 3    3                1                                                NaN
# 4    4                1                                         wheelchair
# 5    5                1                                         wheelchair
# 6    6                2                       disabled_parking, wheelchair
# 7    7                2       ramp, restroom, disabled_parking, wheelchair
# 8    8                2                                                NaN
# 9    9                3                         ramp, restroom, wheelchair
# 10  10                3  elevator, tape_braille, ramp, restroom, disabl...
# ...

# %%
# Now if i want to give the custome name to the column then.[Here we used another data set that is taxonomy.csv]

df=pd.read_csv('/Users/aniketsatishjoshi/Downloads/ohana-api-master/data/sample-csv/taxonomy.csv',
               names=["qeqw",'g','rt','t'])
df
# Out:
#             qeqw                             g         rt  \
# 0    taxonomy_id                          name  parent_id
# 1            101                     Emergency        NaN
# 2         101-01             Disaster Response        101
# 3         101-02                Emergency Cash        101
# 4      101-02-01             Help Pay for Food     101-02
# ..           ...                           ...        ...
# 286    111-01-07              Workplace Rights     111-01
# 287       111-02                     Mediation        111
# 288       111-03                        Notary        111
# 289       111-04                Representation        111
# 290       111-05  Translation & Interpretation        111
#
#                         t
# 0             parent_name
# 1                     NaN
# 2               Emergency
# 3               Emergency
# 4          Emergency Cash
# ..                    ...
# 286  Advocacy & Legal Aid
# 287                 Legal
# ...

# %%
# Now suppose if i give column name more than the present one see what will happen.
df=pd.read_csv('/Users/aniketsatishjoshi/Downloads/ohana-api-master/data/sample-csv/taxonomy.csv',
               names=["qeqw",'g','rt','t','gj'])
df

# It will create 5th column which will be having the value NaN.
# Out:
#             qeqw                             g         rt  \
# 0    taxonomy_id                          name  parent_id
# 1            101                     Emergency        NaN
# 2         101-01             Disaster Response        101
# 3         101-02                Emergency Cash        101
# 4      101-02-01             Help Pay for Food     101-02
# ..           ...                           ...        ...
# 286    111-01-07              Workplace Rights     111-01
# 287       111-02                     Mediation        111
# 288       111-03                        Notary        111
# 289       111-04                Representation        111
# 290       111-05  Translation & Interpretation        111
#
#                         t  gj
# 0             parent_name NaN
# 1                     NaN NaN
# 2               Emergency NaN
# 3               Emergency NaN
# 4          Emergency Cash NaN
# ..                    ...  ..
# 286  Advocacy & Legal Aid NaN
# ...

# %%
# Now suppose if i give column one less column name than the present one see what will happen.
df=pd.read_csv('/Users/aniketsatishjoshi/Downloads/ohana-api-master/data/sample-csv/taxonomy.csv',
               names=["qeqw",'g','rt'])
df

# It means it will treat very 1st column as row indexes.
# Out:
#                                      qeqw          g                    rt
# taxonomy_id                          name  parent_id           parent_name
# 101                             Emergency        NaN                   NaN
# 101-01                  Disaster Response        101             Emergency
# 101-02                     Emergency Cash        101             Emergency
# 101-02-01               Help Pay for Food     101-02        Emergency Cash
# ...                                   ...        ...                   ...
# 111-01-07                Workplace Rights     111-01  Advocacy & Legal Aid
# 111-02                          Mediation        111                 Legal
# 111-03                             Notary        111                 Legal
# 111-04                     Representation        111                 Legal
# 111-05       Translation & Interpretation        111                 Legal
#
# [291 rows x 3 columns]

# %%
# Now suppose if i give column two less column name than the present one see what will happen.
df=pd.read_csv('/Users/aniketsatishjoshi/Downloads/ohana-api-master/data/sample-csv/taxonomy.csv',
               names=["qeqw",'g',])
df

# It will treat 1st two column as row indexes.
# Out:
#                                                qeqw                     g
# taxonomy_id name                          parent_id           parent_name
# 101         Emergency                           NaN                   NaN
# 101-01      Disaster Response                   101             Emergency
# 101-02      Emergency Cash                      101             Emergency
# 101-02-01   Help Pay for Food                101-02        Emergency Cash
# ...                                             ...                   ...
# 111-01-07   Workplace Rights                 111-01  Advocacy & Legal Aid
# 111-02      Mediation                           111                 Legal
# 111-03      Notary                              111                 Legal
# 111-04      Representation                      111                 Legal
# 111-05      Translation & Interpretation        111                 Legal
#
# [291 rows x 2 columns]

# %%
# Some IMP Ponits for Pandas.

# whenever we use pandas remember one thing that it will read only structured data not unstructured. This is 
# it's limitation.

# If we are reading info from the mongodb then we have to convert that data into tabuler format then we can 
# do the read operation.

# Pandas has 2 datatypes.
# 1st "Dataframe"
# 2nd "series"

# 1st we will see about dataframe.
# Whatever the table pandas is creating inside the notebook its data type is called as "dataframe".

# %%
df=pd.read_csv('/Users/aniketsatishjoshi/Downloads/ohana-api-master/data/sample-csv/locations.csv')
df
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# open addresses file in notepad.

df=pd.read_csv('/Users/aniketsatishjoshi/Downloads/ohana-api-master/data/sample-csv/addresses.csv')
df


# Here we import one file whoes name is addresses
# if that we open in notpad we will get one thing that each entity of each row is seperated by ','. 
# Thats why when we read in notebook it is showing in table format.
# Now see the below cell also..
# Out:
#     id  location_id                   address_1  address_2  \
# 0    1            1       2600 Middlefield Road        NaN
# 1    2            2            24 Second Avenue        NaN
# 2    3            3            24 Second Avenue        NaN
# 3    4            4            24 Second Avenue        NaN
# 4    5            5            24 Second Avenue        NaN
# 5    6            6           800 Middle Avenue        NaN
# 6    7            7              500 Arbor Road        NaN
# 7    8            8           800 Middle Avenue        NaN
# 8    9            9       2510 Middlefield Road        NaN
# 9   10           10       1044 Middlefield Road        NaN
# 10  11           11         2140 Euclid Avenue.        NaN
# 11  12           12       1044 Middlefield Road  2nd Floor
# 12  13           13         399 Marine Parkway.        NaN
# 13  14           14          660 Veterans Blvd.        NaN
# 14  15           15        1500 Valencia Street        NaN
# ...

# %%
# open addresses1 file in notepad.
df=pd.read_csv('/Users/aniketsatishjoshi/Downloads/ohana-api-master/data/sample-csv/addresses1.csv')
df
# Here we import one file whoes name is addresses1
# if that we open in notpad we will get one thing that each entity of each row is seperated by '@'. 
# Thats why when we read in notebook it is not showing in table format.
# Out:
#    id@location_id@address_1@address_2@city@state_province@postal_code@country
# 0   1@1@2600 Middlefield Road@@Redwood City@CA@940...
# 1         2@2@24 Second Avenue@@San Mateo@CA@94401@US
# 2         3@3@24 Second Avenue@@San Mateo@CA@94403@US
# 3         4@4@24 Second Avenue@@San Mateo@CA@94401@US
# 4         5@5@24 Second Avenue@@San Mateo@CA@94401@US
# 5   6@6@800 Middle Avenue@@Menlo Park@CA@94025-988...
# 6          7@7@500 Arbor Road@@Menlo Park@CA@94025@US
# 7   8@8@800 Middle Avenue@@Menlo Park@CA@94025-988...
# 8   9@9@2510 Middlefield Road@@Redwood City@CA@940...
# 9   10@10@1044 Middlefield Road@@Redwood City@CA@9...
# 10  11@11@2140 Euclid Avenue.@@Redwood City@CA@940...
# 11  12@12@1044 Middlefield Road@2nd Floor@Redwood ...
# 12  13@13@399 Marine Parkway.@@Redwood City@CA@940...
# 13  14@14@660 Veterans Blvd.@@Redwood City@CA@9406...
# 14  15@15@1500 Valencia Street@@San Francisco@CA@9...
# 15   16@16@1161 South Bernardo@@Sunnyvale@CA@94087@US
# ...

# %%
# now for this we have solution see.
df=pd.read_csv('/Users/aniketsatishjoshi/Downloads/ohana-api-master/data/sample-csv/addresses1.csv',sep='@')
df

# Here we put sep='@'in bracket at last.
# Out:
#     id  location_id                   address_1  address_2  \
# 0    1            1       2600 Middlefield Road        NaN
# 1    2            2            24 Second Avenue        NaN
# 2    3            3            24 Second Avenue        NaN
# 3    4            4            24 Second Avenue        NaN
# 4    5            5            24 Second Avenue        NaN
# 5    6            6           800 Middle Avenue        NaN
# 6    7            7              500 Arbor Road        NaN
# 7    8            8           800 Middle Avenue        NaN
# 8    9            9       2510 Middlefield Road        NaN
# 9   10           10       1044 Middlefield Road        NaN
# 10  11           11         2140 Euclid Avenue.        NaN
# 11  12           12       1044 Middlefield Road  2nd Floor
# 12  13           13         399 Marine Parkway.        NaN
# 13  14           14          660 Veterans Blvd.        NaN
# 14  15           15        1500 Valencia Street        NaN
# ...

# %%
df=pd.read_csv('/Users/aniketsatishjoshi/Downloads/ohana-api-master/data/sample-csv/addresses1.csv')
df
# Out:
#     id  location_id                   address_1  address_2  \
# 0    1            1       2600 Middlefield Road        NaN
# 1    2            2            24 Second Avenue        NaN
# 2    3            3            24 Second Avenue        NaN
# 3    4            4            24 Second Avenue        NaN
# 4    5            5            24 Second Avenue        NaN
# 5    6            6           800 Middle Avenue        NaN
# 6    7            7              500 Arbor Road        NaN
# 7    8            8           800 Middle Avenue        NaN
# 8    9            9       2510 Middlefield Road        NaN
# 9   10           10       1044 Middlefield Road        NaN
# 10  11           11         2140 Euclid Avenue.        NaN
# 11  12           12       1044 Middlefield Road  2nd Floor
# 12  13           13         399 Marine Parkway.        NaN
# 13  14           14          660 Veterans Blvd.        NaN
# 14  15           15        1500 Valencia Street        NaN
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# If we want to know what is the data types of each and every columns.

df.dtypes
# Out:
# id                 int64
# location_id        int64
# address_1         object
# address_2         object
# city              object
# state_province    object
# postal_code       object
# country           object
# dtype: object

# %%
df=pd.read_csv('/Users/aniketsatishjoshi/Downloads/ohana-api-master/data/sample-csv/addresses.csv',sep=',')
df
# Out:
#     id  location_id                   address_1  address_2  \
# 0    1            1       2600 Middlefield Road        NaN
# 1    2            2            24 Second Avenue        NaN
# 2    3            3            24 Second Avenue        NaN
# 3    4            4            24 Second Avenue        NaN
# 4    5            5            24 Second Avenue        NaN
# 5    6            6           800 Middle Avenue        NaN
# 6    7            7              500 Arbor Road        NaN
# 7    8            8           800 Middle Avenue        NaN
# 8    9            9       2510 Middlefield Road        NaN
# 9   10           10       1044 Middlefield Road        NaN
# 10  11           11         2140 Euclid Avenue.        NaN
# 11  12           12       1044 Middlefield Road  2nd Floor
# 12  13           13         399 Marine Parkway.        NaN
# 13  14           14          660 Veterans Blvd.        NaN
# 14  15           15        1500 Valencia Street        NaN
# ...

# %%
df.head(2)
# Out:
#    id  location_id              address_1 address_2          city  \
# 0   1            1  2600 Middlefield Road       NaN  Redwood City
# 1   2            2       24 Second Avenue       NaN     San Mateo
#
#   state_province postal_code country
# 0             CA       94063      US
# 1             CA       94401      US

# %%
df.tail(3)
# Out:
#     id  location_id                   address_1  address_2           city  \
# 18  19           19         19 West 39th Avenue        NaN      San Mateo
# 19  20           21          123 El Camino Real        NaN        Belmont
# 20  21           22  2013 Avenue of the fellows  Suite 100  San Francisco
#
#    state_province postal_code country
# 18             CA       94403      US
# 19             CA       94002      US
# 20             CA       94103      US

# %%
df.columns
# Out:
# Index(['id', 'location_id', 'address_1', 'address_2', 'city', 'state_province',
#        'postal_code', 'country'],
#       dtype='object')

# %%
# IF i want only 2/3 columns from all the columns then 

a = df["city"]
a
# Out:
# 0            Redwood City
# 1               San Mateo
# 2               San Mateo
# 3               San Mateo
# 4               San Mateo
# 5              Menlo Park
# 6              Menlo Park
# 7              Menlo Park
# 8            Redwood City
# 9            Redwood City
# 10           Redwood City
# 11           Redwood City
# 12           Redwood City
# 13           Redwood City
# 14          San Francisco
# 15              Sunnyvale
# 16    South San Francisco
# 17           Redwood City
# 18              San Mateo
# 19                Belmont
# 20          San Francisco
# Name: city, dtype: object

# %%
# Now here we will see about the 2nd datatype of pandas i.e. "series"
# whenevre you are going to pull out one single column or one single row from the table then pandas lib. is 
# going to represent that as series.

# Here we are pulling out only one column.
a = df["city"]
type(a)

# Now see the datatype it is "series".
# Out:
# pandas.core.series.Series

# %%
# Here we are pulling out only one row.
a = df[0]
type(a)
# Now see the datatype it is "series".

# From both above and the this same cell we can conclude that combination of dif dif series data types is
# called dataframe.
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
# If we want multiple columns in o/p then we have to pass there in list.
a = df[["location_id","city","postal_code"]]
a
# Out:
#     location_id                 city postal_code
# 0             1         Redwood City       94063
# 1             2            San Mateo       94401
# 2             3            San Mateo       94403
# 3             4            San Mateo       94401
# 4             5            San Mateo       94401
# 5             6           Menlo Park  94025-9881
# 6             7           Menlo Park       94025
# 7             8           Menlo Park  94025-9881
# 8             9         Redwood City       94063
# 9            10         Redwood City       94063
# 10           11         Redwood City       94061
# 11           12         Redwood City       94063
# 12           13         Redwood City       94065
# 13           14         Redwood City       94063
# 14           15        San Francisco       94110
# 15           16            Sunnyvale       94087
# 16           17  South San Francisco       94080
# 17           18         Redwood City       94063
# ...

# %%
a = df[["location_id","city","postal_code"]]
type(a)

# Now see the datatype of this it will show us dataframe because we ask to show more than 2 column.
# Out:
# pandas.core.frame.DataFrame

# %%
# Now here we give the only one column name so as per till knowledge we are expecting dattpye as series but see
# o/p it is showing dataframe . because we put that column name "city" in list []

type(df[['city']])

#        |-----| 
#           |
#           |
#           |-------------> list

# %%
# PANDAS WITH EXCEL

# %%
pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
ls
# Out:
#  MongoDB/
# 1#_iNEURON_PYTHON_4DEC_&_5DEC_2021.ipynb
# 10#_iNEURON_PYTHON_12FEB_&_13FEB_2022.ipynb
# 10.1#_iNEURON_PYTHON_12FEB_&_13FEB_2022.ipynb
# 10.2#_iNEURON_PYTHON_12FEB_&_13FEB_2022.ipynb
# 11#_iNEURON_PYTHON_19FEB_&_20FEB_2022.ipynb
# 12#_iNEURON_PYTHON_26FEB_&_27FEB_2022.ipynb
# 13#_iNEURON_PYTHON_5MAR_&_6MAR_2022.ipynb
# 2#_iNEURON_PYTHON_18DEC_&_19DEC_2021.ipynb
# 3#_iNEURON_PYTHON_20DEC_&_21DEC_2021.ipynb
# 4#_iNEURON_PYTHON_23DEC_2021.ipynb
# 5#_iNEURON_PYTHON_8JAN_&_9JAN_2022.ipynb
# 6#_iNEURON_PYTHON_15JAN_&_16JAN_2022.ipynb
# 7#_iNEURON_PYTHON_22JAN_&_23JAN_2022.ipynb
# 7.1#_iNEURON_PYTHON_22JAN_&_23JAN_2022.ipynb
# 8#_iNEURON_PYTHON_29JAN_&_30JAN_2022.ipynb
# 9#_iNEURON_PYTHON_5FEB_&_6FEB_2022.ipynb
# DATA SET/
# FILES/
# PycharmProjects/
# glass.csv
# glass.data
# google.txt
# ineuron.db
# jobdb.db
# ohana-api-master/
# person.db
# sample-excel-master/

# %%
import pandas as pd

# %%
# Remember the following step.

# %%
df = pd.ExcelFile('LUSID Excel - Manage Orders.xlsx')

# %%
df.sheet_names
# Out:
# ['Executions', 'Orders', 'Allocations', 'Placements', 'Blocks']

# %%
# Mention the sheet name into bracket then it will show result in consol.

df=pd.read_excel('LUSID Excel - Manage Orders.xlsx',sheet_name = "Executions")
df
# Out:
#     Unnamed: 0                                   Unnamed: 1  \
# 0          NaN  This sheet allows you to manage executions:
# 1          NaN                           1. List executions
# 2          NaN                             2. Get execution
# 3          NaN                         3. Upsert executions
# 4          NaN                                          NaN
# ..         ...                                          ...
# 65         NaN                                          NaN
# 66         NaN                                          NaN
# 67         NaN                                          NaN
# 68         NaN                                          NaN
# 69         NaN                                          NaN
#
#            Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 0                 NaN        NaN        NaN        NaN        NaN        NaN
# 1                 NaN        NaN        NaN        NaN        NaN        NaN
# ...

# %%
df.keys()
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
#        'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
#        'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17',
#        'Unnamed: 18'],
#       dtype='object')

# %%
pd.read_excel('LUSID Excel - Manage Orders.xlsx',sheet_name = "Allocations")
# Out:
#     Unnamed: 0                                    Unnamed: 1       Unnamed: 2  \
# 0          NaN  This sheet allows you to manage Allocations:              NaN
# 1          NaN                            1. ListAllocations              NaN
# 2          NaN                              2. GetAllocation              NaN
# 3          NaN                          3. UpsertAllocations              NaN
# 4          NaN                                           NaN              NaN
# ..         ...                                           ...              ...
# 60         NaN                                           NaN              NaN
# 61         NaN                                           NaN              NaN
# 62         NaN                                           NaN             Code
# 63         NaN                                           NaN  MyAllocation001
# 64         NaN                                           NaN  MyAllocation002
#
# ...

# %%
for i in df.sheet_names:
    pd.read_excel('LUSID Excel - Manage Orders.xlsx',sheet_name=i)

# %%
# URL
# https://github.com/datasciencedojo/datasets/blob/master/titanic.csv

pd.read_csv('https://github.com/datasciencedojo/datasets/blob/master/titanic.csv')

# if we execute this it will show us error.
# So to open this above link and then click on 'raw' and copy that link into it. which we have done in following 
# cell then it will execute.

# %%
# URL
# https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv

pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
pd.read_csv('https://raw.githubusercontent.com/codeforamerica/ohana-api/master/data/sample-csv/phones.csv')
# Out:
#     id  contact_id  location_id  organization_id  service_id  country_prefix  \
# 0    1         NaN          1.0              NaN         NaN             NaN
# 1    2         NaN          1.0              NaN         NaN             NaN
# 2    3         NaN          2.0              NaN         NaN             NaN
# 3    4         NaN          2.0              NaN         NaN             NaN
# 4    5         NaN          3.0              NaN         NaN             NaN
# 5    6         NaN          3.0              NaN         NaN             NaN
# 6    7         NaN          4.0              NaN         NaN             NaN
# 7    8         NaN          4.0              NaN         NaN             NaN
# 8    9         NaN          5.0              NaN         NaN             NaN
# 9   10         NaN          5.0              NaN         NaN             NaN
# 10  11         NaN          6.0              NaN         NaN             NaN
# ...
