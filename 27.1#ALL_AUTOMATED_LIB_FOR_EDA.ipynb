# %% [markdown]
# # Autoviz

# %%
# !pip install autoviz

# %%
pip install --upgrade --user pyqt5==5.13
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pathlib
# Out:
# ...
#   Using cached pathlib-1.0.1.tar.gz (49 kB)
#   Preparing metadata (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> [20 lines of output]
#       Traceback (most recent call last):
#         File "<string>", line 36, in <module>
#         File "<pip-setuptools-caller>", line 34, in <module>
#         File "/private/var/folders/g0/424mq_gn0jq76h7qlxtqdg_h0000gn/T/pip-install-ai7j4u7j/pathlib_8a89809f7f1a44efad38cdbbd29aa48c/setup.py", line 30, in <module>
#           url='https://pathlib.readthedocs.org/',
#         File "/opt/anaconda3/lib/python3.7/site-packages/setuptools/_distutils/core.py", line 109, in setup
#           _setup_distribution = dist = klass(attrs)
#         File "/opt/anaconda3/lib/python3.7/site-packages/setuptools/dist.py", line 457, in __init__
#           for ep in metadata.entry_points(group='distutils.setup_keywords'):
# ...

# %%
from autoviz.AutoViz_Class import AutoViz_Class

AV = AutoViz_Class()
# Out:
# Imported AutoViz_Class version: 0.0.81. Call using:
#     from autoviz.AutoViz_Class import AutoViz_Class
#     AV = AutoViz_Class()
#     AV.AutoViz(filename, sep=',', depVar='', dfte=None, header=0, verbose=0,
#                             lowess=False,chart_format='svg',max_rows_analyzed=150000,max_cols_analyzed=30)
# Note: verbose=0 or 1 generates charts and displays them in your local Jupyter notebook.
#       verbose=2 saves plots in your local machine under AutoViz_Plots directory and does not display charts.

# %%
filename = "titanic.csv"
sep = ","
dft = AV.AutoViz(
    filename,
    sep=",",
    depVar="",
    dfte=None,
    header=0,
    verbose=0,
    lowess=False,
    chart_format="svg",
    max_rows_analyzed=150000,
    max_cols_analyzed=30,
)
# Out:
# Shape of your Data Set: (891, 12)
# ############## C L A S S I F Y I N G  V A R I A B L E S  ####################
# Classifying variables in data set...
#     Number of Numeric Columns =  2
#     Number of Integer-Categorical Columns =  3
#     Number of String-Categorical Columns =  1
#     Number of Factor-Categorical Columns =  0
#     Number of String-Boolean Columns =  1
#     Number of Numeric-Boolean Columns =  1
#     Number of Discrete String Columns =  2
#     Number of NLP String Columns =  0
#     Number of Date Time Columns =  0
#     Number of ID Columns =  2
#     Number of Columns to Delete =  0
#     12 Predictors classified...
#         This does not include the Target column(s)
#         4 variables removed since they were ID or low-information variables
# Number of All Scatter Plots = 3
# Time to run AutoViz (in seconds) = 2.350
#
#  ###################### VISUALIZATION Completed ########################

# %% [markdown]
# # D Tale

# %%
pip install dtale
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.7/12.7 MB 642.7 kB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 471.9 kB/s eta 0:00:0000:0100:03
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 642.7/642.7 KB 1.3 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 845.2/845.2 KB 1.2 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.4/40.4 KB 1.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.1/47.1 KB 1.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.2/85.2 MB 2.1 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 KB 2.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.6/9.6 MB 2.7 MB/s eta 0:00:0000:0100:01
# ...

# %%
conda update -n base -c defaults conda
# Out:
# ...
# Solving environment: /
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/osx-64::scikit-learn==1.0.2=py37hae1ba45_1
#   - defaults/noarch::nltk==3.7=pyhd3eb1b0_0
#   - defaults/osx-64::scikit-learn-intelex==2021.5.0=py37hecd8cb5_0
#   - defaults/osx-64::_anaconda_depends==2021.11=py37_0
#   - defaults/osx-64::anaconda==custom=py37_1
# -
# ...
#   - defaults/osx-64::docutils-0.18.1-py37hecd8cb5_2, defaults/osx-64::sphinx-1.8.5-py37_0
#   - defaults/noarch::sphinx-4.4.0-pyhd3eb1b0_0, defaults/osx-64::docutils-0.17.1-py37hecd8cb5done
#
# ## Package Plan ##
#
#   environment location: /opt/anaconda3
#
#   added / updated specs:
#     - conda
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     jpeg-9e                    |       hca72f7f_0         225 KB
# ...

# %%
import seaborn as sns 
df=sns.load_dataset('titanic')
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
import dtale
dtale.show(df)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /var/folders/g0/424mq_gn0jq76h7qlxtqdg_h0000gn/T/ipykernel_36900/1002931050.py in <module>
# ----> 1 import dtale
#       2 dtale.show(df)
#
# /opt/anaconda3/lib/python3.7/site-packages/dtale/__init__.py in <module>
#       8
#       9 # flake8: NOQA
# ---> 10 from dtale.app import show, get_instance, instances, offline_chart  # isort:skip
#      11 from dtale.cli.loaders import LOADERS  # isort:skip
#      12 from dtale.global_state import update_id  # isort:skip
#
# /opt/anaconda3/lib/python3.7/site-packages/dtale/app.py in <module>
#      20
#      21 import requests
# ---> 22 from flask_compress import Compress
#      23 from six import PY3
#      24
#
# /opt/anaconda3/lib/python3.7/site-packages/flask_compress/__init__.py in <module>
# ----> 1 from .flask_compress import Compress
#       2
# ...

# %% [markdown]
# # Sweetviz

# %%
# !pip install sweetviz
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.1/15.1 MB 4.5 MB/s eta 0:00:0000:0100:01
# ...

# %%
import seaborn as sns 
df=sns.load_dataset('titanic')
df.head()

import sweetviz as sv
report=sv.analyze(df)
report.show_html('Sweet_Report.html')
# Out:
#                                              |      | [  0%]   00:00 -> (? left)
# Report Sweet_Report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
 # run above cell or open following link.

# %%
# file:///Users/aniketsatishjoshi/Downloads/Autoviz-main/Sweet_Report.html

# %% [markdown]
# # Pandas-Visual-Analysis

# %%
# !pip install pandas-visual-analysis
# Out:
# ...
#      |████████████████████████████████| 111 kB 613 kB/s eta 0:00:01
# ...
#   Created wheel for blinker: filename=blinker-1.4-py3-none-any.whl size=13478 sha256=4a27f4f226811e9211dc449c3d05ad78c56ea1b854dcfa3040bf87be080859e1
#   Stored in directory: /Users/aniketsatishjoshi/Library/Caches/pip/wheels/22/f5/18/df711b66eb25b21325c132757d4314db9ac5e8dabeaf196eab
# Successfully built blinker
# ...

# %%
# This lib use only when data is less complex.

# %%
import seaborn as sns

# %%
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'exercise', 'flights', 'fmri', 'gammas', 'geyser', 'iris', 'mpg', 'penguins', 'planets', 'taxis', 'tips', 'titanic']

# %%
df=sns.load_dataset('iris')
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
from pandas_visual_analysis import VisualAnalysis
VisualAnalysis(df)

# %% [markdown]
# # Dataprep

# %%
# !pip install dataprep
# Out:
# ...
#      |████████████████████████████████| 9.5 MB 4.4 MB/s eta 0:00:01     |███████████████████████████     | 8.0 MB 4.4 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 180 kB 7.3 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 50 kB 6.9 MB/s eta 0:00:011
# ...
#      |████████████████████████████████| 95 kB 2.3 MB/s eta 0:00:01
# ...
#   Using cached Jinja2-3.1.1-py3-none-any.whl (132 kB)
# ...
#      |████████████████████████████████| 570 kB 3.5 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 943 kB 4.5 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 32.6 MB 1.9 MB/s eta 0:00:01     |███████████▌                    | 11.8 MB 3.5 MB/s eta 0:00:06
# ...
#      |████████████████████████████████| 78 kB 1.4 MB/s eta 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 288 kB 2.1 MB/s eta 0:00:01
# ...

# %%
from dataprep.datasets import load_dataset
from dataprep.eda import create_report
df = load_dataset("titanic")
create_report(df)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/g0/424mq_gn0jq76h7qlxtqdg_h0000gn/T/ipykernel_36900/1318132808.py in <module>
# ----> 1 from dataprep.datasets import load_dataset
#       2 from dataprep.eda import create_report
#       3 df = load_dataset("titanic")
#       4 create_report(df)
#
# ModuleNotFoundError: No module named 'dataprep'

# %% [markdown]
# # LUX

# %%
pip install lux-api
# Out:
# ...
#      |████████████████████████████████| 127 kB 1.9 MB/s eta 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 40 kB 4.0 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 812 kB 4.4 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 2.5 MB 5.2 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 238 kB 7.6 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 42 kB 1.7 MB/s  eta 0:00:01
# ...
#   Created wheel for lux-api: filename=lux_api-0.5.1-py3-none-any.whl size=185620 sha256=fadaed39ecb7526980c0e5210ce5d650dbd1ebc0b11e5776d4abfb2c2e6352b4
#   Stored in directory: /Users/aniketsatishjoshi/Library/Caches/pip/wheels/30/50/dc/d963e60d29e93842892c038df8d1a2bf50df51be4ac3b1dfb2
# ...

# %% [markdown]
# # klib

# %%
# !pip install klib

# %%
import seaborn as sns 
df=sns.load_dataset('titanic')
df.head()

import klib

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
klib.cat_plot(df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/g0/424mq_gn0jq76h7qlxtqdg_h0000gn/T/ipykernel_36900/2222831409.py in <module>
# ----> 1 klib.cat_plot(df)
#
# /opt/anaconda3/lib/python3.7/site-packages/klib/describe.py in cat_plot(data, figsize, top, bottom, bar_color_top, bar_color_bottom)
#     116         data[col] = data[col].rolling(2, min_periods=1).mean()
#     117
# --> 118         value_counts_idx_top = [elem[:20] for elem in value_counts_idx_top]
#     119         value_counts_idx_bot = [elem[:20] for elem in value_counts_idx_bot]
#     120         sum_top = sum(value_counts_top)
#
# /opt/anaconda3/lib/python3.7/site-packages/klib/describe.py in <listcomp>(.0)
#     116         data[col] = data[col].rolling(2, min_periods=1).mean()
#     117
# --> 118         value_counts_idx_top = [elem[:20] for elem in value_counts_idx_top]
# ...

# %%
klib.corr_mat(df)
# Out:
# <style type="text/css">
# #T_18670_row0_col0, #T_18670_row0_col4, #T_18670_row0_col5, #T_18670_row1_col1, #T_18670_row1_col3, #T_18670_row1_col4, #T_18670_row1_col6, #T_18670_row1_col7, #T_18670_row2_col2, #T_18670_row2_col5, #T_18670_row2_col6, #T_18670_row2_col7, #T_18670_row3_col1, #T_18670_row3_col3, #T_18670_row3_col4, #T_18670_row3_col5, #T_18670_row4_col0, #T_18670_row4_col1, #T_18670_row4_col3, #T_18670_row4_col4, #T_18670_row4_col5, #T_18670_row5_col0, #T_18670_row5_col2, #T_18670_row5_col3, #T_18670_row5_col4, #T_18670_row5_col5, #T_18670_row6_col1, #T_18670_row6_col2, #T_18670_row6_col6, #T_18670_row6_col7, #T_18670_row7_col1, #T_18670_row7_col2, #T_18670_row7_col6, #T_18670_row7_col7 {
#   color: None;
# }
# ...

# %%
klib.corr_plot(df)
# Out:
# <AxesSubplot:title={'center':'Feature-correlation (pearson)'}>

# %%
klib.dist_plot(df)
# Out:
# <AxesSubplot:xlabel='fare', ylabel='Density'>

# %%
klib.missingval_plot(df)
# Out:
# GridSpec(6, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
df_clean=klib.data_cleaning(df)
# Out:
# Shape of cleaned data: (784, 15)Remaining NAs: 692
#
# Changes:
# Dropped rows: 107
#      of which 107 duplicates. (Rows: [47, 76, 77, 87, 95, 101, 121, 133, 173, 196, 198, 201, 213, 223, 241, 260, 274, 295, 300, 304, 313, 320, 324, 335, 343, 354, 355, 358, 359, 364, 368, 384, 409, 410, 413, 418, 420, 425, 428, 431, 454, 459, 464, 466, 470, 476, 481, 485, 488, 490, 494, 500, 511, 521, 522, 526, 531, 560, 563, 564, 568, 573, 588, 589, 598, 601, 612, 613, 614, 635, 636, 640, 641, 644, 646, 650, 656, 666, 674, 692, 696, 709, 732, 733, 734, 738, 739, 757, 758, 760, 773, 790, 792, 800, 808, 832, 837, 838, 844, 846, 859, 863, 870, 877, 878, 884, 886])
# Dropped columns: 0
#      of which 0 single valued.     Columns: []
# Dropped missing values: 177
# Reduced memory by at least: 0.06 MB (-75.0%)

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 784 entries, 0 to 783
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     784 non-null    int8
#  1   pclass       784 non-null    int8
#  2   sex          784 non-null    category
#  3   age          678 non-null    Float32
#  4   sibsp        784 non-null    int8
#  5   parch        784 non-null    int8
#  6   fare         784 non-null    Float32
#  7   embarked     782 non-null    category
#  8   class        784 non-null    category
#  9   who          784 non-null    category
#  10  adult_male   784 non-null    boolean
#  11  deck         202 non-null    category
#  12  embark_town  782 non-null    category
#  13  alive        784 non-null    category
#  14  alone        784 non-null    boolean
# dtypes: Float32(2), boolean(2), category(7), int8(4)
# memory usage: 20.4 KB

# %%
# Go through this link and  then go through some features which are present in folowing link 
# https://pypi.org/project/klib/.
