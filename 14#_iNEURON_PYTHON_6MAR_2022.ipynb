# %% [markdown]
# # 6th MAR

# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
dx=df.dtypes
dx
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
dx['Pclass']
# Out:
# dtype('int64')

# %%
dx[:3]
# Out:
# PassengerId    int64
# Survived       int64
# Pclass         int64
# dtype: object

# %%
dx[0:100:1]
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.dropna()

# It will drop the entire row even if there is one NaN value in compelete row or column.

# Press shift and tab then see the parameter in it.
# df.dropna(axis=1) It will drop the column where most no. of null values are present. Y-axix.
# df.dropna(axis=0) It will drop the row where most no. null value are present. X-axis.
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df  # See one thing that all NaN value are again come back. means when we perform any drop nan operation then 
    # it will not drop permannatly, it will drop only for that perticular cell o/p.
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.dropna(axis=1) # see the column count.
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris    male      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
# 2                               Heikkinen, Miss. Laina  female      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1      0
# 4                             Allen, Mr. William Henry    male      0      0
# ...

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.dropna(axis=0) # See the row count.
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Now if we want to drop the perticular data from the table which is having NaN value either in row or column 
# then use df.dropna(inplace=Ture) by defalut inplace=false. But if we make it True it will delete data 
# permannatly.

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df

# %%
df.dropna(axis=0,thresh=800) # It means if there are 800 non NaN record i will not drop it.

# %%
df

# %%
df.dropna(axis=1 ,thresh=800) # It means if there are 800 non NaN record i will not drop it. 

# Here it will drop the AGE and cabin column.
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris    male      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
# 2                               Heikkinen, Miss. Laina  female      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1      0
# 4                             Allen, Mr. William Henry    male      0      0
# ...

# %%
df.dropna(axis=0 ,how ='any') # By default how value is 'any' but we can change it to the 'all'

# any ---> it means if any NaN value is present then drop row or column.
# all ---> it means if all values are NaN then drop row or column.
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# df.fillna("sudh")
# OR
df.fillna(value="sudh")
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.fillna(value=df['Age'].mean())
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
df.groupby('Survived').describe()
# Out:
#          PassengerId                                                     \
#                count        mean         std  min     25%    50%    75%
# Survived
# 0              549.0  447.016393  260.640469  1.0  211.00  455.0  675.0
# 1              342.0  444.368421  252.358840  2.0  250.75  439.5  651.5
#
#                 Pclass            ... Parch        Fare                        \
#             max  count      mean  ...   75%  max  count       mean        std
# Survived                          ...
# 0         891.0  549.0  2.531876  ...   0.0  6.0  549.0  22.117887  31.388207
# 1         890.0  342.0  1.950292  ...   1.0  5.0  342.0  48.395408  66.596998
#
#
#           min      25%   50%   75%       max
# Survived
# 0         0.0   7.8542  10.5  26.0  263.0000
# 1         0.0  12.4750  26.0  57.0  512.3292
#
# [2 rows x 48 columns]

# %%
type(df.groupby('Survived').describe())
# Out:
# pandas.core.frame.DataFrame

# %%
df.groupby('Survived').describe().loc[0]
# Out:
# PassengerId  count    549.000000
#              mean     447.016393
#              std      260.640469
#              min        1.000000
#              25%      211.000000
#              50%      455.000000
#              75%      675.000000
#              max      891.000000
# Pclass       count    549.000000
#              mean       2.531876
#              std        0.735805
#              min        1.000000
#              25%        2.000000
#              50%        3.000000
#              75%        3.000000
#              max        3.000000
# Age          count    424.000000
#              mean      30.626179
#              std       14.172110
#              min        1.000000
#              25%       21.000000
#              50%       28.000000
#              75%       39.000000
#              max       74.000000
# SibSp        count    549.000000
#              mean       0.553734
#              std        1.288399
#              min        0.000000
# ...

# %%
df.groupby('Survived').describe().loc[0]['PassengerId']
# Out:
# count    549.000000
# mean     447.016393
# std      260.640469
# min        1.000000
# 25%      211.000000
# 50%      455.000000
# 75%      675.000000
# max      891.000000
# Name: 0, dtype: float64

# %%
# OR

# %%
# Groupby on Survived with ['PassengerId']

df.groupby('Survived').describe()['PassengerId']
# Out:
#           count        mean         std  min     25%    50%    75%    max
# Survived
# 0         549.0  447.016393  260.640469  1.0  211.00  455.0  675.0  891.0
# 1         342.0  444.368421  252.358840  2.0  250.75  439.5  651.5  890.0

# %%
df.groupby('Survived').describe()['PassengerId'].transpose()
# Out:
# Survived           0           1
# count     549.000000  342.000000
# mean      447.016393  444.368421
# std       260.640469  252.358840
# min         1.000000    2.000000
# 25%       211.000000  250.750000
# 50%       455.000000  439.500000
# 75%       675.000000  651.500000
# max       891.000000  890.000000

# %%
# Groupby on Survived with ['Age']

df.groupby('Survived').describe()['Age']
# Out:
#           count       mean        std   min   25%   50%   75%   max
# Survived
# 0         424.0  30.626179  14.172110  1.00  21.0  28.0  39.0  74.0
# 1         290.0  28.343690  14.950952  0.42  19.0  28.0  36.0  80.0

# %%
df.groupby('Survived').describe()['Age'].transpose()
# Out:
# Survived           0           1
# count     424.000000  290.000000
# mean       30.626179   28.343690
# std        14.172110   14.950952
# min         1.000000    0.420000
# 25%        21.000000   19.000000
# 50%        28.000000   28.000000
# 75%        39.000000   36.000000
# max        74.000000   80.000000

# %%
# Groupby on Pclass with ['Age']

df.groupby('Pclass').describe()['Age']
# Out:
#         count       mean        std   min   25%   50%   75%   max
# Pclass
# 1       186.0  38.233441  14.802856  0.92  27.0  37.0  49.0  80.0
# 2       173.0  29.877630  14.001077  0.67  23.0  29.0  36.0  70.0
# 3       355.0  25.140620  12.495398  0.42  18.0  24.0  32.0  74.0

# %%
df.groupby('Pclass').describe()['Age'].transpose()
# Out:
# Pclass           1           2           3
# count   186.000000  173.000000  355.000000
# mean     38.233441   29.877630   25.140620
# std      14.802856   14.001077   12.495398
# min       0.920000    0.670000    0.420000
# 25%      27.000000   23.000000   18.000000
# 50%      37.000000   29.000000   24.000000
# 75%      49.000000   36.000000   32.000000
# max      80.000000   70.000000   74.000000

# %%
# Groupby on Pclass with ['Fare']

df.groupby('Pclass').describe()['Fare']
# Out:
#         count       mean        std  min       25%      50%   75%       max
# Pclass
# 1       216.0  84.154687  78.380373  0.0  30.92395  60.2875  93.5  512.3292
# 2       184.0  20.662183  13.417399  0.0  13.00000  14.2500  26.0   73.5000
# 3       491.0  13.675550  11.778142  0.0   7.75000   8.0500  15.5   69.5500

# %%
df.groupby('Pclass').describe()['Fare'].transpose()
# Out:
# Pclass           1           2           3
# count   216.000000  184.000000  491.000000
# mean     84.154687   20.662183   13.675550
# std      78.380373   13.417399   11.778142
# min       0.000000    0.000000    0.000000
# 25%      30.923950   13.000000    7.750000
# 50%      60.287500   14.250000    8.050000
# 75%      93.500000   26.000000   15.500000
# max     512.329200   73.500000   69.550000

# %%
# df.groupby('Survived').describe().loc[0]['PassengerId']

# O/P of above is...

# count    549.000000
# mean     447.016393
# std      260.640469
# min        1.000000
# 25%      211.000000
# 50%      455.000000
# 75%      675.000000
# max      891.000000
# Name: 0, dtype: float64

# If i want to extract further detail then...

df.groupby('Survived').describe().loc[0]['PassengerId'][2]

# We get std. Deviation from above list.
# Out:
# 260.64046905714144

# %%
df1 = pd.read_csv('bank.csv',sep=";")
df1
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
l = []
for i in df1['education'].unique() : 
    l.append(df1[df1["education"] == i])
l
# Out:
# [      age            job   marital education default  balance housing loan  \
#  0      30     unemployed   married   primary      no     1787      no   no
#  9      43       services   married   primary      no      -88     yes  yes
#  18     25    blue-collar    single   primary      no     -221     yes   no
#  26     55    blue-collar   married   primary      no      627     yes   no
#  36     78        retired  divorced   primary      no      229      no   no
#  ...   ...            ...       ...       ...     ...      ...     ...  ...
#  4480   23    blue-collar   married   primary      no     1158     yes   no
#  4485   53    blue-collar   married   primary      no      238     yes   no
#  4486   37    blue-collar   married   primary      no      378     yes   no
#  4499   45    blue-collar  divorced   primary      no      942      no   no
#  4503   60  self-employed   married   primary      no      362      no  yes
#
# ...

# %%
len(l)
# Out:
# 4

# %%
df1.head()
# Out:
#    age          job  marital  education default  balance housing loan  \
# 0   30   unemployed  married    primary      no     1787      no   no
# 1   33     services  married  secondary      no     4789     yes  yes
# 2   35   management   single   tertiary      no     1350     yes   no
# 3   30   management  married   tertiary      no     1476     yes  yes
# 4   59  blue-collar  married  secondary      no        0     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# 1  cellular   11   may       220         1    339         4  failure  no
# 2  cellular   16   apr       185         1    330         1  failure  no
# 3   unknown    3   jun       199         4     -1         0  unknown  no
# 4   unknown    5   may       226         1     -1         0  unknown  no

# %%
df2 = l[0]

# %%
df2
# Out:
#       age            job   marital education default  balance housing loan  \
# 0      30     unemployed   married   primary      no     1787      no   no
# 9      43       services   married   primary      no      -88     yes  yes
# 18     25    blue-collar    single   primary      no     -221     yes   no
# 26     55    blue-collar   married   primary      no      627     yes   no
# 36     78        retired  divorced   primary      no      229      no   no
# ...   ...            ...       ...       ...     ...      ...     ...  ...
# 4480   23    blue-collar   married   primary      no     1158     yes   no
# 4485   53    blue-collar   married   primary      no      238     yes   no
# 4486   37    blue-collar   married   primary      no      378     yes   no
# 4499   45    blue-collar  divorced   primary      no      942      no   no
# 4503   60  self-employed   married   primary      no      362      no  yes
#
# ...

# %%
df3 = l[1]

# %%
df3
# Out:
#       age          job  marital  education default  balance housing loan  \
# 1      33     services  married  secondary      no     4789     yes  yes
# 4      59  blue-collar  married  secondary      no        0     yes   no
# 7      39   technician  married  secondary      no      147     yes   no
# 10     39     services  married  secondary      no     9374     yes   no
# 11     43       admin.  married  secondary      no      264     yes   no
# ...   ...          ...      ...        ...     ...      ...     ...  ...
# 4514   38  blue-collar  married  secondary      no     1205     yes   no
# 4515   32     services   single  secondary      no      473     yes   no
# 4516   33     services  married  secondary      no     -333     yes   no
# 4518   57   technician  married  secondary      no      295      no   no
# 4519   28  blue-collar  married  secondary      no     1137      no   no
#
#        contact  day month  duration  campaign  pdays  previous poutcome   y
# ...

# %%
df41=l[2]
df41
# Out:
#       age            job   marital education default  balance housing loan  \
# 2      35     management    single  tertiary      no     1350     yes   no
# 3      30     management   married  tertiary      no     1476     yes  yes
# 5      35     management    single  tertiary      no      747      no   no
# 6      36  self-employed   married  tertiary      no      307     yes   no
# 8      41   entrepreneur   married  tertiary      no      221     yes   no
# ...   ...            ...       ...       ...     ...      ...     ...  ...
# 4501   34     management   married  tertiary      no      297     yes   no
# 4506   42     unemployed  divorced  tertiary      no     -166      no   no
# 4509   51     technician   married  tertiary      no     2506      no   no
# 4517   57  self-employed   married  tertiary     yes    -3313     yes  yes
# 4520   44   entrepreneur    single  tertiary      no     1136     yes  yes
#
# ...

# %%
df51=l[3]
df51
# Out:
#       age          job   marital education default  balance housing loan  \
# 20     38   management  divorced   unknown      no        0     yes   no
# 27     67      retired   married   unknown      no      696      no   no
# 49     61       admin.   married   unknown      no     4629     yes   no
# 132    43  blue-collar   married   unknown     yes     -715     yes   no
# 133    48       admin.   married   unknown      no        0     yes   no
# ...   ...          ...       ...       ...     ...      ...     ...  ...
# 4337   73      retired   married   unknown      no      519      no   no
# 4342   50  blue-collar   married   unknown      no     2284     yes   no
# 4428   48  blue-collar   married   unknown      no      439     yes   no
# 4471   59   management   married   unknown      no     3534      no   no
# 4508   42       admin.   married   unknown      no      642     yes  yes
#
#         contact  day month  duration  campaign  pdays  previous poutcome    y
# ...

# %%
# concatination operation with dataframes

pd.concat([df2,df3])
# Out:
#       age          job   marital  education default  balance housing loan  \
# 0      30   unemployed   married    primary      no     1787      no   no
# 9      43     services   married    primary      no      -88     yes  yes
# 18     25  blue-collar    single    primary      no     -221     yes   no
# 26     55  blue-collar   married    primary      no      627     yes   no
# 36     78      retired  divorced    primary      no      229      no   no
# ...   ...          ...       ...        ...     ...      ...     ...  ...
# 4514   38  blue-collar   married  secondary      no     1205     yes   no
# 4515   32     services    single  secondary      no      473     yes   no
# 4516   33     services   married  secondary      no     -333     yes   no
# 4518   57   technician   married  secondary      no      295      no   no
# 4519   28  blue-collar   married  secondary      no     1137      no   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome    y
# ...

# %%
df2=df2.head()
df2
# Out:
#     age          job   marital education default  balance housing loan  \
# 0    30   unemployed   married   primary      no     1787      no   no
# 9    43     services   married   primary      no      -88     yes  yes
# 18   25  blue-collar    single   primary      no     -221     yes   no
# 26   55  blue-collar   married   primary      no      627     yes   no
# 36   78      retired  divorced   primary      no      229      no   no
#
#       contact  day month  duration  campaign  pdays  previous poutcome    y
# 0    cellular   19   oct        79         1     -1         0  unknown   no
# 9    cellular   17   apr       313         1    147         2  failure   no
# 18    unknown   23   may       250         1     -1         0  unknown   no
# 26    unknown    5   may       247         1     -1         0  unknown   no
# 36  telephone   22   oct        97         1     -1         0  unknown  yes

# %%
df3=df3.head()
df3
# Out:
#     age          job  marital  education default  balance housing loan  \
# 1    33     services  married  secondary      no     4789     yes  yes
# 4    59  blue-collar  married  secondary      no        0     yes   no
# 7    39   technician  married  secondary      no      147     yes   no
# 10   39     services  married  secondary      no     9374     yes   no
# 11   43       admin.  married  secondary      no      264     yes   no
#
#      contact  day month  duration  campaign  pdays  previous poutcome   y
# 1   cellular   11   may       220         1    339         4  failure  no
# 4    unknown    5   may       226         1     -1         0  unknown  no
# 7   cellular    6   may       151         2     -1         0  unknown  no
# 10   unknown   20   may       273         1     -1         0  unknown  no
# 11  cellular   17   apr       113         2     -1         0  unknown  no

# %%
pd.concat([df2,df3]) # By default it will concat by row
# Out:
#     age          job   marital  education default  balance housing loan  \
# 0    30   unemployed   married    primary      no     1787      no   no
# 9    43     services   married    primary      no      -88     yes  yes
# 18   25  blue-collar    single    primary      no     -221     yes   no
# 26   55  blue-collar   married    primary      no      627     yes   no
# 36   78      retired  divorced    primary      no      229      no   no
# 1    33     services   married  secondary      no     4789     yes  yes
# 4    59  blue-collar   married  secondary      no        0     yes   no
# 7    39   technician   married  secondary      no      147     yes   no
# 10   39     services   married  secondary      no     9374     yes   no
# 11   43       admin.   married  secondary      no      264     yes   no
#
#       contact  day month  duration  campaign  pdays  previous poutcome    y
# 0    cellular   19   oct        79         1     -1         0  unknown   no
# ...

# %%
df2.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'y'],
#       dtype='object')

# %%
df3.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'y'],
#       dtype='object')

# %%
df2 = df2.head()[['age', 'job', 'marital']]    # If i want only 3 columns then.
df2
# Out:
#     age          job   marital
# 0    30   unemployed   married
# 9    43     services   married
# 18   25  blue-collar    single
# 26   55  blue-collar   married
# 36   78      retired  divorced

# %%
df3 = df3.head()[['age','job','marital']]
df3
# Out:
#     age          job  marital
# 1    33     services  married
# 4    59  blue-collar  married
# 7    39   technician  married
# 10   39     services  married
# 11   43       admin.  married

# %%
df7 = pd.concat([df2,df3],axis=0)
df7 

# Here we have done concatination on basis of row.
# Out:
#     age          job   marital
# 0    30   unemployed   married
# 9    43     services   married
# 18   25  blue-collar    single
# 26   55  blue-collar   married
# 36   78      retired  divorced
# 1    33     services   married
# 4    59  blue-collar   married
# 7    39   technician   married
# 10   39     services   married
# 11   43       admin.   married

# %%
df5 = pd.concat([df2,df3],axis=1)
df5 

# Here we have done concatination on basis of column.
# Out:
#      age          job   marital   age          job  marital
# 0   30.0   unemployed   married   NaN          NaN      NaN
# 1    NaN          NaN       NaN  33.0     services  married
# 4    NaN          NaN       NaN  59.0  blue-collar  married
# 7    NaN          NaN       NaN  39.0   technician  married
# 9   43.0     services   married   NaN          NaN      NaN
# 10   NaN          NaN       NaN  39.0     services  married
# 11   NaN          NaN       NaN  43.0       admin.  married
# 18  25.0  blue-collar    single   NaN          NaN      NaN
# 26  55.0  blue-collar   married   NaN          NaN      NaN
# 36  78.0      retired  divorced   NaN          NaN      NaN

# %%
df5['age']
# Out:
#      age   age
# 0   30.0   NaN
# 1    NaN  33.0
# 4    NaN  59.0
# 7    NaN  39.0
# 9   43.0   NaN
# 10   NaN  39.0
# 11   NaN  43.0
# 18  25.0   NaN
# 26  55.0   NaN
# 36  78.0   NaN

# %% [markdown]
# # NEW TOPIC loc and iloc

# %%
# Difference Between loc and iloc.
# loc :- Allways try to take named indexs where as
# iloc:- try to take default integer indexes.

# %%
# Now If we want to extract age colum from df5 then it will give us 2 columns.
# Now if we want one specific column out of 2 Age columns then.. We will call to iloc.

# df5.iloc[row no : , column no]
df5.iloc[:,3] 

# It means all row and 3rd column.indexes start from 0 thats why we use 3 for 2nd age column in
# dataframe.
# Out:
# 0      NaN
# 1     33.0
# 4     59.0
# 7     39.0
# 9      NaN
# 10    39.0
# 11    43.0
# 18     NaN
# 26     NaN
# 36     NaN
# Name: age, dtype: float64

# %%
df5.iloc[:,[3,4]]
# Out:
#      age          job
# 0    NaN          NaN
# 1   33.0     services
# 4   59.0  blue-collar
# 7   39.0   technician
# 9    NaN          NaN
# 10  39.0     services
# 11  43.0       admin.
# 18   NaN          NaN
# 26   NaN          NaN
# 36   NaN          NaN

# %%
df5.iloc[[4,5],[3,4]]
# Out:
#      age       job
# 9    NaN       NaN
# 10  39.0  services

# %%
# As we says that loc :- Allways try to take named indexs

df5.loc[[9,10],['age']] # So here named index is ['age'] in it. that's why it is called loc takes named index.
# Out:
#      age   age
# 9   43.0   NaN
# 10   NaN  39.0

# %%
df2
# Out:
#     age          job   marital
# 0    30   unemployed   married
# 9    43     services   married
# 18   25  blue-collar    single
# 26   55  blue-collar   married
# 36   78      retired  divorced

# %%
# Mala row madhe 9 aani 18 pahige aani column madhe "job" aani "marital" madhun. using loc

df2.loc[[9,18],['job','marital']]
# Out:
#             job  marital
# 9      services  married
# 18  blue-collar   single

# %%
# Mala row madhe 9 aani 18 pahige column madhe "job" aani "marital" madhun. using iloc

df2.iloc[[1,2] , [1,2]]
# Out:
#             job  marital
# 9      services  married
# 18  blue-collar   single

# %%
l=[4,5,6,7,8]
l
# Out:
# [4, 5, 6, 7, 8]

# %%
type(l)
# Out:
# list

# %%
k=np.array(l)
k
# Out:
# array([4, 5, 6, 7, 8])

# %%
type(k)
# Out:
# numpy.ndarray

# %%
pd.Series(k)
# Out:
# 0    4
# 1    5
# 2    6
# 3    7
# 4    8
# dtype: int64

# %%
asj1=pd.Series(k , index=['a','b','asj','kum','c'])
asj1
# Out:
# a      4
# b      5
# asj    6
# kum    7
# c      8
# dtype: int64

# %%
asj1['kum']
# Out:
# 7

# %%
# iloc

# %%
asj1.iloc['kum'] # It will give us error.

# TypeError: Cannot index by location index with a non-integer key.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/g0/424mq_gn0jq76h7qlxtqdg_h0000gn/T/ipykernel_7783/1959593749.py in <module>
# ----> 1 asj1.iloc['kum'] # it will give us error.
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     929
#     930             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 931             return self._getitem_axis(maybe_callable, axis=axis)
#     932
#     933     def _is_scalar_access(self, key: tuple):
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1561             key = item_from_zerodim(key)
#    1562             if not is_integer(key):
# -> 1563                 raise TypeError("Cannot index by location index with a non-integer key")
#    1564
#    1565             # validate the location
#
# ...

# %%
asj1.iloc[3]
# Out:
# 7

# %%
# loc

# %%
asj1.loc['asj']
# Out:
# 6

# %%
asj1.loc[3]  # It will give us error.

# KeyError: 3
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 3
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
# We create another array here.

asj2=pd.Series(np.array([4,5,6,7,8]),index=[11,21,31,41,51])
asj2
# Out:
# 11    4
# 21    5
# 31    6
# 41    7
# 51    8
# dtype: int64

# %%
# Now if i try to use iloc here see what will happen.
asj2.iloc[11]

# It will give us error now see what is happening here as we said iloc is taking only int value as index then 
# it should be executed , but it is not executed heer because iloc is only takes int indexes but it takes 
# default one i.e. default indexes (0,1,2,3...)

# In above also whatever the indexes we have mention are integer as type but these are given by us not an
# system generated one so it is called as named indexes.

# so in this case use loc.
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/g0/424mq_gn0jq76h7qlxtqdg_h0000gn/T/ipykernel_7783/224196832.py in <module>
#       1 # Now if i try to use iloc here see what will happen.
# ----> 2 asj2.iloc[11]
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     929
#     930             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 931             return self._getitem_axis(maybe_callable, axis=axis)
#     932
#     933     def _is_scalar_access(self, key: tuple):
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1564
#    1565             # validate the location
# -> 1566             self._validate_integer(key, axis)
#    1567
#    1568             return self.obj._ixs(key, axis=axis)
#
# ...

# %%
asj2.loc[11]
# Out:
# 4

# %%
import pandas as pd
import numpy as np

# %%
dfx=pd.DataFrame(np.random.randint(3,6,(4,5)),index=['a','b','c','d'],columns=['x','y','z','u','v'])
dfx
# Out:
#    x  y  z  u  v
# a  4  4  3  3  5
# b  3  3  5  5  3
# c  5  3  4  5  4
# d  5  3  3  3  3

# %%
# dfx.loc[['c','d'],['z','u']]

dfx.loc[['c','d'],['z','u']]

#      OR
# Out:
#    z  u
# c  4  5
# d  3  3

# %%
# Here we used defalut indexes.

dfx.iloc[[2,3],[2,3]]

#    OR
# Out:
#    z  u
# c  4  5
# d  3  3

# %%
# Here we used range of defalut indexes.

dfx.iloc[2:,2:4]
# Out:
#    z  u
# c  4  5
# d  3  3

# %%
# We can access the elements by two ways.

# 1st

dfx['x']

#   OR
# Out:
# a    4
# b    3
# c    5
# d    5
# Name: x, dtype: int64

# %%
# 1st

dfx[['x']]

# %%
# 2nd

dfx.x
# Out:
# a    4
# b    3
# c    5
# d    5
# Name: x, dtype: int64

# %%
dfx['New']=dfx['x']+dfx.x
dfx
# Out:
#    x  y  z  u  v  New
# a  4  4  3  3  5    8
# b  3  3  5  5  3    6
# c  5  3  4  5  4   10
# d  5  3  3  3  3   10

# %%
dfx.drop('x')  # It wil give us error. by default it is taking axix=0 i.e. x-axixs = 0

# but whatever the column we are trying to drop from the table it is present in the column not in row so we 
# have to mention that axix=1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/g0/424mq_gn0jq76h7qlxtqdg_h0000gn/T/ipykernel_7783/325053938.py in <module>
# ----> 1 dfx.drop('x')  # It wil give us error. by default it is taking axix=0 i.e. x-axixs = 0
#       2
#       3 # but whatever the column we are trying to drop from the table it is present in the column not in row so we
#       4 # have to mention that axix=1
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4911             level=level,
#    4912             inplace=inplace,
# ...

# %%
dfx.drop('x',axis=1)
# Out:
#    y  z  u  v  New
# a  4  3  3  5    8
# b  3  5  5  3    6
# c  3  4  5  4   10
# d  3  3  3  3   10

# %%
dfx.drop('a')
#     OR
# dfx.drop('a',axis=0)
# Out:
#    x  y  z  u  v  New
# b  3  3  5  5  3    6
# c  5  3  4  5  4   10
# d  5  3  3  3  3   10

# %%
dfx
# Out:
#    x  y  z  u  v  New
# a  4  4  3  3  5    8
# b  3  3  5  5  3    6
# c  5  3  4  5  4   10
# d  5  3  3  3  3   10

# %%
# As we drop one colum and one row from table in above cell but if we call dfx again it wil give us entire data 
# in o/p.

# so fro this we have to mention one parameter inside the bracket i.e inplace parameter.
# inplace= True

dfx.drop('x', axis=1,inplace= True)
dfx
# Out:
#    y  z  u  v  New
# a  4  3  3  5    8
# b  3  5  5  3    6
# c  3  4  5  4   10
# d  3  3  3  3   10

# %%
dfx.drop('a',axis=0,inplace= True)
dfx
# Out:
#    y  z  u  v  New
# b  3  5  5  3    6
# c  3  4  5  4   10
# d  3  3  3  3   10

# %%
dfx
# Out:
#    y  z  u  v  New
# b  3  5  5  3    6
# c  3  4  5  4   10
# d  3  3  3  3   10

# %%
np.random.seed(30)
dfx1=pd.DataFrame(np.random.randn(4,5),index=['a','b','c','d'],columns=['x','y','z','u','v'])
dfx1
# Out:
#           x         y         z         u         v
# a -1.264053  1.527905 -0.970711  0.470560 -0.100697
# b  0.303793 -1.725962  1.585095  0.134297 -1.106855
# c  1.578226  0.107498 -0.764048 -0.775189  1.383847
# d  0.760385 -0.285646  0.538367 -2.083897  0.937782

# %%
# Now If i want all -ve values from this above table then

# %%
dfx1.values[dfx1.values<0]

# code wise it is correct but it is a problem of python 3.
# Out:
# array([-1.26405266, -0.97071094, -0.10069672, -1.72596243, -1.10685547,
#        -0.76404783, -0.77518851, -0.28564551, -2.08389663])

# %%
dfx1.values[dfx1.iloc[0:5]<0]
# code wise it is correct but it is a problem of python 3.
# Out:
# array([-1.26405266, -0.97071094, -0.10069672, -1.72596243, -1.10685547,
#        -0.76404783, -0.77518851, -0.28564551, -2.08389663])

# %%
# Now if i want only -ve values with ther indexes fom above column then.

c=dfx1.values[dfx1.values<0]
for i in dfx1.columns:
    for j in dfx1.index:
        if dfx1.loc[j,i] in c:
            print(j,i,dfx1[j][i])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'a'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df2
# Out:
#     age          job   marital
# 0    30   unemployed   married
# 9    43     services   married
# 18   25  blue-collar    single
# 26   55  blue-collar   married
# 36   78      retired  divorced

# %%
df3
# Out:
#     age          job  marital
# 1    33     services  married
# 4    59  blue-collar  married
# 7    39   technician  married
# 10   39     services  married
# 11   43       admin.  married

# %%
pd.merge(df2,df3,on='age') 

# It will check which age no. [i.e. 30 ,43] like that it is comman in both table and depend upon that it will 
# fetch the record.

# Age 43 is comman in both table thats why it show that one record.
# Out:
#    age     job_x marital_x   job_y marital_y
# 0   43  services   married  admin.   married

# %%
# how = 'left'

pd.merge(df2,df3, on = 'age', how = 'left') 

# It will give us every record from left table ie. df2 and cooman data from both table.
# Out:
#    age        job_x marital_x   job_y marital_y
# 0   30   unemployed   married     NaN       NaN
# 1   43     services   married  admin.   married
# 2   25  blue-collar    single     NaN       NaN
# 3   55  blue-collar   married     NaN       NaN
# 4   78      retired  divorced     NaN       NaN

# %%
# how = 'right'

pd.merge(df2,df3, on = 'age', how = 'right')
# Out:
#    age     job_x marital_x        job_y marital_y
# 0   33       NaN       NaN     services   married
# 1   59       NaN       NaN  blue-collar   married
# 2   39       NaN       NaN   technician   married
# 3   39       NaN       NaN     services   married
# 4   43  services   married       admin.   married

# %%
# how = 'outer'

pd.merge(df2,df3, on = 'age', how = 'outer') # It means all data.
# Out:
#    age        job_x marital_x        job_y marital_y
# 0   30   unemployed   married          NaN       NaN
# 1   43     services   married       admin.   married
# 2   25  blue-collar    single          NaN       NaN
# 3   55  blue-collar   married          NaN       NaN
# 4   78      retired  divorced          NaN       NaN
# 5   33          NaN       NaN     services   married
# 6   59          NaN       NaN  blue-collar   married
# 7   39          NaN       NaN   technician   married
# 8   39          NaN       NaN     services   married

# %%
df2
# Out:
#     age          job   marital
# 0    30   unemployed   married
# 9    43     services   married
# 18   25  blue-collar    single
# 26   55  blue-collar   married
# 36   78      retired  divorced

# %%
df2 = df2.set_index('age')
df2
# Out:
#              job   marital
# age
# 30    unemployed   married
# 43      services   married
# 25   blue-collar    single
# 55   blue-collar   married
# 78       retired  divorced

# %%
df3
# Out:
#     age          job  marital
# 1    33     services  married
# 4    59  blue-collar  married
# 7    39   technician  married
# 10   39     services  married
# 11   43       admin.  married

# %%
df3 = df3.set_index('age')
df3
# Out:
#              job  marital
# age
# 33      services  married
# 59   blue-collar  married
# 39    technician  married
# 39      services  married
# 43        admin.  married

# %%
df2.join(df3)
# It will give us error because column name is same in both table.
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/g0/424mq_gn0jq76h7qlxtqdg_h0000gn/T/ipykernel_7783/2495703548.py in <module>
# ----> 1 df2.join(df3)
#       2 # It will give us error because column name is same in both table.
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in join(self, other, on, how, lsuffix, rsuffix, sort)
#    9098         """
#    9099         return self._join_compat(
# -> 9100             other, on=on, how=how, lsuffix=lsuffix, rsuffix=rsuffix, sort=sort
#    9101         )
#    9102
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _join_compat(self, other, on, how, lsuffix, rsuffix, sort)
#    9136                 right_index=True,
#    9137                 suffixes=(lsuffix, rsuffix),
# -> 9138                 sort=sort,
#    9139             )
#    9140         else:
#
# ...

# %%
df2.rename(columns={'job' : 'job1' , "marital" : 'marital1'},inplace=True)
df2
# Out:
#             job1  marital1
# age
# 30    unemployed   married
# 43      services   married
# 25   blue-collar    single
# 55   blue-collar   married
# 78       retired  divorced

# %%
df3
# Out:
#              job  marital
# age
# 33      services  married
# 59   blue-collar  married
# 39    technician  married
# 39      services  married
# 43        admin.  married

# %%
df2.join(df3,how ='inner') # only Comman from both.
# Out:
#          job1 marital1     job  marital
# age
# 43   services  married  admin.  married

# %%
df2.join(df3,how ='outer')  # Everything from both.
# Out:
#             job1  marital1          job  marital
# age
# 25   blue-collar    single          NaN      NaN
# 30    unemployed   married          NaN      NaN
# 33           NaN       NaN     services  married
# 39           NaN       NaN   technician  married
# 39           NaN       NaN     services  married
# 43      services   married       admin.  married
# 55   blue-collar   married          NaN      NaN
# 59           NaN       NaN  blue-collar  married
# 78       retired  divorced          NaN      NaN

# %%
df2.join(df3,how ='left')    # Everything from left and comman from both.
# Out:
#             job1  marital1     job  marital
# age
# 25   blue-collar    single     NaN      NaN
# 30    unemployed   married     NaN      NaN
# 43      services   married  admin.  married
# 55   blue-collar   married     NaN      NaN
# 78       retired  divorced     NaN      NaN

# %%
df2.join(df3,how ='right') # Everything from right and comman from both.
# Out:
#          job1 marital1          job  marital
# age
# 33        NaN      NaN     services  married
# 39        NaN      NaN   technician  married
# 39        NaN      NaN     services  married
# 43   services  married       admin.  married
# 59        NaN      NaN  blue-collar  married

# %%
pd.merge(df2,df3,left_on='job1',right_on='job')
# Out:
#           job1 marital1          job  marital
# 0     services  married     services  married
# 1     services  married     services  married
# 2  blue-collar   single  blue-collar  married
# 3  blue-collar  married  blue-collar  married
